# %%
import os
import pdb #debug
import time
import shutil
import math
import re
import csv
import numpy as np
import matplotlib.pyplot as plt

import networkx as nx
from graphviz import Digraph
from graphviz import Source

from IPython.display import display, JSON
from scipy import stats

# %matplotlib inline
my_client = fbl.get_client()

# %% [markdown]
# # R23E10

# %%
#turn on breakpoints?
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
data = my_client.executeNLPquery('clear')
# Out:
# [FBL NLP 2025-07-30 16:19:36,739] NLP successfully parsed query.

# %%
# !git init
# !git remote add origin https://github.com/sgarnell/archive
# Out:
# Reinitialized existing Git repository in /home/ffbo/ffbo/.git/
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/sgarnell/archive.git (fetch)
# origin	https://github.com/sgarnell/archive.git (push)

# %%
# Stage the notebook file
# !git add 'pathfinder_v1_1.ipynb'

# Commit the changes
# !git commit -m "Auto commit from Jupyter for {notebook_name}"

# Push to GitHub
# !git push origin main  # Replace 'main' with 'master' if needed
# Out:
# [main dcf037a] Auto commit from Jupyter for {notebook_name}
#  1 file changed, 8790 insertions(+)
#  create mode 100644 pathfinder_v1_1.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 31.38 KiB | 6.28 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sgarnell/archive.git
#    368ffdb..dcf037a  main -> main

# %% [markdown]
# ## NOI to remove

# %%
data = my_client.executeNLPquery("remove $SIP$")
# Out:
# [FBL NLP 2024-07-31 18:07:18,324] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $SMP$")
# Out:
# [FBL NLP 2024-07-31 18:07:27,833] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $ExR$")
# Out:
# [FBL NLP 2024-07-26 22:45:00,432] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $FB$")
# Out:
# [FBL NLP 2024-07-31 18:07:51,948] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $LH$")
# Out:
# [FBL NLP 2024-07-31 18:09:38,031] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $LN$")
# Out:
# [FBL NLP 2024-07-31 18:10:35,440] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $LAL$")
# Out:
# [FBL NLP 2024-07-31 18:10:35,440] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $MBON$")
# Out:
# [FBL NLP 2024-07-31 18:10:40,733] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $CRE$")
# Out:
# [FBL NLP 2024-07-31 18:10:45,363] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $PPL$")
# Out:
# [FBL NLP 2024-07-31 18:09:38,031] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $PF$")
# Out:
# [FBL NLP 2024-07-31 18:09:38,031] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $FB1H$")
# Out:
# [FBL NLP 2024-07-29 04:18:07,802] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $hDelta$")
# Out:
# [FBL NLP 2024-07-27 04:23:46,874] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $vDelta$")
# Out:
# [FBL NLP 2024-07-27 04:24:35,925] NLP successfully parsed query.

# %% [markdown]
# # MB & Kenyon

# %%
data = my_client.executeNLPquery("show $MBON21$")
# Out:
# [FBL NLP 2025-06-04 01:04:48,506] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $MBON$ red")
# Out:
# [FBL NLP 2025-05-04 02:58:49,194] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add postsynaptic $FB$ neruons with at least 30 synapses")
# Out:
# [FBL NLP 2025-05-04 02:58:51,157] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $FB$ lime")
# Out:
# [FBL NLP 2025-05-04 02:58:54,745] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic $KC$ neruons with at least 35 synapses")
# Out:
# [FBL NLP 2025-05-04 02:58:59,160] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $KC$ yellow")
# Out:
# [FBL NLP 2025-05-04 02:59:07,193] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic /r(.*)AL-(.*)/r neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-05-03 02:53:29,536] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic /r(.*)ILN(.*)/r neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-05-03 02:50:21,108] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic /r(.*)VA1d(.*)/r neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-05-03 02:50:47,391] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic /r(.*)VP[123](.*)/r neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-05-03 02:52:02,565] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic /r(.*)M_l(.*)/r neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-05-03 02:53:24,805] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $VP$ blue")
# Out:
# [FBL NLP 2025-04-28 03:49:10,685] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("show $lLN2F_b$")
# Out:
# [FBL NLP 2025-04-26 05:06:34,803] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add postsynaptic $AL-$ neruons")
# Out:
# [FBL NLP 2025-04-26 05:07:26,787] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add presynaptic $VA1d$ neruons")
# Out:
# [FBL NLP 2025-04-26 05:23:38,997] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $ORN$ neruons")
# Out:
# [FBL NLP 2025-04-26 05:07:34,757] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add postsynaptic $KC$ neruons with at least 50 synapses")
# Out:
# [FBL NLP 2025-04-26 05:07:38,711] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add postsynaptic $MBON$ neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-04-26 05:07:45,569] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add postsynaptic $FB$ neruons with at least 25 synapses")
# Out:
# [FBL NLP 2025-04-26 05:08:30,033] NLP successfully parsed query.

# %% [markdown]
# # MBON11 and 21 Network with DPM and APL

# %%
data = my_client.executeNLPquery("clear")
# Out:
# [FBL NLP 2025-07-25 23:26:18,240] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rVP3+(.*)/r")
# Out:
# [FBL NLP 2025-05-23 02:20:34,376] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rVP2_(.*)/r")
# Out:
# [FBL NLP 2025-05-23 02:20:35,998] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /raMe12(.*)/r")
# Out:
# [FBL NLP 2025-05-23 02:20:37,731] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rKCg-s[123](.*)/r")
# Out:
# [FBL NLP 2025-05-23 02:20:39,500] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rAPL|DPM/r")
# Out:
# [FBL NLP 2025-05-23 02:20:40,796] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rPPL105|PPL101|PPL102/r")
# Out:
# [FBL NLP 2025-05-23 02:21:03,352] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rMBON01|MBON05|MBON09/r")
# Out:
# [FBL NLP 2025-07-25 23:08:42,108] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove /r(.*)_L(.*)/r")
# Out:
# [FBL NLP 2025-05-23 02:22:25,353] NLP successfully parsed query.

# %% [markdown]
# # ExR->FB->CRE

# %%
data = my_client.executeNLPquery("add $ExR5$")
# Out:
# [FBL NLP 2025-02-17 04:09:29,866] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB4Y$")
# Out:
# [FBL NLP 2025-02-17 04:09:32,243] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5M$")
# Out:
# [FBL NLP 2025-02-17 04:09:35,553] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5N$")
# Out:
# [FBL NLP 2025-02-17 04:09:37,287] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5W$")
# Out:
# [FBL NLP 2025-02-17 04:09:38,740] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5K$")
# Out:
# [FBL NLP 2025-02-17 04:09:40,697] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5Y$")
# Out:
# [FBL NLP 2025-02-17 04:09:42,722] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5H$")
# Out:
# [FBL NLP 2025-02-17 04:09:44,478] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5A_$")
# Out:
# [FBL NLP 2025-02-17 04:09:46,754] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE107$")
# Out:
# [FBL NLP 2025-02-17 04:09:49,453] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("clear")
# Out:
# [FBL NLP 2025-07-28 00:34:35,201] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rMBON09(.*)R_1(.*)/r")
# Out:
# [FBL NLP 2025-07-27 19:33:40,894] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rMBON05(.*)L_1(.*)/r")
# Out:
# [FBL NLP 2025-07-28 00:33:33,051] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rMBON01(.*)R_1(.*)/r")
# Out:
# [FBL NLP 2025-07-28 00:34:43,390] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /rLHCENT5(.*)R_1(.*)/r")
# Out:
# [FBL NLP 2025-07-28 00:34:45,546] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $DPM$")
# Out:
# [FBL NLP 2025-07-24 18:52:44,423] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $APL$")
# Out:
# [FBL NLP 2025-07-25 05:27:38,497] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("remove $DPM$")
# Out:
# [FBL NLP 2025-07-30 01:15:10,583] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $MBON$")
# Out:
# [FBL NLP 2025-07-25 05:27:39,038] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery(f"remove {neuronsToExclude}")
# Out:
# [FBL NLP 2025-07-29 19:23:16,416] NLP successfully parsed query.

# %% [markdown]
# # Start

# %%
# noi = 'PAM01'
noi = "MBON13"
neuronsToExclude = '/r(.*)KC(.*)/r'
noi2 = f"/r(.*){noi}(.*)_R(.*)/r"
prePost = 'post'
nSys = 75
nFilter = '/r(.*)(.*)(.*)/r'
nplQuery = f"show {noi2} neurons"
print(nplQuery)
data = my_client.executeNLPquery(nplQuery)
# Out:
# show /r(.*)MBON13(.*)_R(.*)/r neurons
# [FBL NLP 2025-07-30 23:43:47,963] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery(f"add {prePost}synaptic {nFilter} neurons with at least {nSys} synapses")
# Out:
# [FBL NLP 2025-07-30 23:43:50,709] NLP successfully parsed query.

# %%
# ⏱️ Timer start
start_time = time.time()

neurons = my_client.NLP_result.neurons
hashids = list(neurons.keys())
names = [neurons[k]['uname'] for k in hashids]

# 🧠 Synapse collection
preSynapses = []
postSynapses = []

for i, hashid in enumerate(hashids):
    res = my_client.getInfo(hashid)
    data = res["data"]

    if "connectivity" in data:
        presyn = data["connectivity"]["pre"]["details"]
        postsyn = data["connectivity"]["post"]["details"]

        for syn in presyn:
            preSynapses.append(("pre", syn["syn_uname"], names[i], syn["uname"],
                                syn["s_rid"], syn["number"], True))

        for syn in postsyn:
            postSynapses.append(("post", syn["syn_uname"], names[i], syn["uname"],
                                 syn["s_rid"], syn["number"], True))

# 🧩 NumPy structured arrays
dtype = [('type', 'U4'), ('syn_uname', 'U100'), ('neuron_name', 'U100'),
         ('uname', 'U100'), ('s_rid', 'U100'), ('number', 'f8'), ('valid', 'bool')]

pre_array = np.array(preSynapses, dtype=dtype)
post_array = np.array(postSynapses, dtype=dtype)

# 🔍 Filter out 'segment' entries efficiently
pre_array = pre_array[np.char.find(pre_array['uname'], 'segment') == -1]
post_array = post_array[np.char.find(post_array['uname'], 'segment') == -1]

connectivity = {"hashids": hashids, "names": names, "pre_array": pre_array, "post_array": post_array}

# 📊 Dictionary construction
postSynNumberDict = {}
preSynNumberDict = {}

def process_array(array, synNumberDict, synType):
    neuron_names = np.unique(array['neuron_name'])
    for neuron in neuron_names:
        mask = array['neuron_name'] == neuron
        syn_data = array[mask]
        syn_numbers = syn_data['number']

        if syn_numbers.size == 0:
            continue

        z_scores = stats.zscore(syn_numbers)

        if np.any(np.isnan(z_scores)):
            array['valid'][mask] = False
            print(f'\033[93m{neuron} Error: Nan Value Found in array\033[0m')
            continue

        zmax = np.max(z_scores)
        norm_scores = 1 - ((zmax - z_scores) / zmax)

        print(f'\033[92m{neuron}: {synType}SynZmax= {zmax}\033[0m')

        for uname, rid, z, norm in zip(syn_data['syn_uname'], syn_data['s_rid'], z_scores, norm_scores):
            synNumberDict[rid] = [uname, z, norm]

process_array(connectivity["post_array"], postSynNumberDict, "post")
process_array(connectivity["pre_array"], preSynNumberDict, "pre")

# 🕒 Timing metrics
numberOfNodes = len(names)
end_time = time.time()
elapsed_time = end_time - start_time

avSynCalc_time = elapsed_time / (len(pre_array) + len(post_array))
avNeuronCalc_time = elapsed_time / numberOfNodes

avSynCalc_time = 10

if elapsed_time > avSynCalc_time:
    gvLayoutEngine = 'neato'
    gGraphvizMode = 'sgd'
else:
    gvLayoutEngine = 'sfdp'
    gGraphvizMode = 'spring'

print ("No. of HashIDs= " + str( len(hashids)))
print ("No. of names= " + str( numberOfNodes ))
print ("No. of preSynapses= " + str( len(preSynapses)))
print ("No. of postSynapses= " + str( len(postSynapses)))
print(f"Elapsed time: {elapsed_time:.2f} seconds")
print(f"Avg. time per synapse: {avSynCalc_time:.4f} seconds")
print(f"Avg. time per neuron: {avNeuronCalc_time:.4f} seconds")
print(f"Graphviz  set to Engine: {gvLayoutEngine} and Mode:{gGraphvizMode} ")
# Out:
# CRE055_R_4: postSynZmax= 8.07681297964699
# CRE055_R_7: postSynZmax= 10.124631026372281
# CRE077_R_1: postSynZmax= 17.231426564892573
# FB5AB_R_1: postSynZmax= 8.371254639631475
# LHCENT11_R_1: postSynZmax= 12.147042482818199
# LHCENT4_R_1: postSynZmax= 17.201682181428684
# LHPV10d1_R_1: postSynZmax= 16.79095222802764
# LHPV5e1_R_1: postSynZmax= 11.048634034868734
# MBON13(a'2)_R_1: postSynZmax= 9.447689171149328
# SIP087_R_1: postSynZmax= 13.925904124714496
# SIP090(SCB027)_R_1: postSynZmax= 7.864065007266726
# SMP127_R_1: postSynZmax= 8.996685730824936
# SMP177_R_1: postSynZmax= 23.497247004329584
# CRE055_R_4: preSynZmax= 6.422637842423315
# CRE055_R_7: preSynZmax= 6.110577467056945
# CRE077_R_1: preSynZmax= 12.032125978621236
# FB5AB_R_1: preSynZmax= 12.272526317225608
# LHCENT11_R_1: preSynZmax= 10.509663821979757
# LHCENT4_R_1: preSynZmax= 12.50096256996425
# LHPV10d1_R_1: preSynZmax= 9.164443322154797
# LHPV5e1_R_1: preSynZmax= 14.992141481771528
# MBON13(a'2)_R_1: preSynZmax= 14.058125716748588
# SIP087_R_1: preSynZmax= 12.534725923732603
# SIP090(SCB027)_R_1: preSynZmax= 8.49995241001561
# SMP127_R_1: preSynZmax= 8.74444818785799
# SMP177_R_1: preSynZmax= 12.588018734271447
# No. of HashIDs= 13
# No. of names= 13
# No. of preSynapses= 9392
# No. of postSynapses= 9572
# Elapsed time: 56.86 seconds
# Avg. time per synapse: 10.0000 seconds
# Avg. time per neuron: 4.3740 seconds
# Graphviz  set to Engine: neato and Mode:sgd

# %% [markdown]
# ### optional

# %%
#output to CSV if needed
with open('preOutput.csv','w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['type','syn_name','uname','s_rid','hashid','number'])
    writer.writerows(preSynapses)

# %%
with open('postOutput.csv','w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['type','syn_name','uname','s_rid','hashid','number'])
    writer.writerows(postSynapses)

# %% [markdown]
# ### continue from here

# %%
res = my_client.getConnectivity()
nodes = dict(res.graph.nodes(data=True))
edges = list(res.graph.edges(data=True))

#sample outputs 
#print(edges)
#print(edges[0][0])
#display(JSON(nodes))
#print(edges)

# %%
display(JSON(nodes, expanded = False))
display(JSON(edges, expanded = False))

# %%
# Step 1: Add nodes (and catch malformed ones)
G = nx.DiGraph()

for e_pre in nodes:
    try:
        uname_val = nodes[e_pre]['uname']
        G.add_node(e_pre, uname=uname_val)
    except KeyError as e:
        print(f"⚠️ Node {e_pre} skipped: missing 'uname'")
        continue

# Step 2: Add edges
for edge in edges:
    try:
        G.add_edge(edge[0], edge[1])
    except KeyError as e:
        print(f"⚠️ Edge {edge} skipped: {e.args[0]}")
        continue

# Step 3: Compute centrality
centralityDict = nx.betweenness_centrality(G, normalized=True)

# Step 4: Assign centrality only to valid graph nodes
for node in G.nodes():
    G.nodes[node]['centrality'] = centralityDict.get(node, 0.0)

# %%
#GraphViz
#Rndering the final output ot NeuGFX

#false = line , ortho is curved for example
gvSplines = "false"

graph_struct = {'verbose':'false',
                'splines': gvSplines,
                'pad': '0.5',
                'ranksep': '1.5',
                'concentrate': 'true',
                'newrank': 'true',
                'rankdir': 'LR'}


edgeFontSize = '4.0'
edgeFontColor = "#40e0d0"
edgeFontName = "Ariel"
gvSize = '50,50'
#gvLayout = 'dot'
#gvLayout = 'sfdp'

g = Digraph('G', 
            filename ='G_ex.gv',
            graph_attr = {  'size': gvSize,
                            'layout':gvLayoutEngine,
                            'fontcolor':edgeFontColor,
                            'fontsize':edgeFontSize,
                            'fontname':edgeFontName,
                            'overlap_scaling':'2',
                            'rotation':'0',
                            'mode':gGraphvizMode,
                            'beautify':'true',
                            'splines': 'curved',
                            'arrowsize': '0.5',
                            'overlap': 'false',
                            'pad': '0.1',
                            'quadtree':'true',
                            'nodesep': '0.3',
                            'outputorder': 'edgesfirst',
                            'ranksep': '0.2',
                            'bgcolor': '#212529',
                            'colorscheme':'rdylgn8',
                            'concentrate': 'true',
                            'newrank': 'true',
                            'rankdir': 'LR'})

# %%
def calcColor(normalizedScore):
    
    retlist = []
    pw_default = 0.1
    pc_default = 'gray'
    pw = pw_default
    pc = pc_default

    if normalizedScore is None:
        pw = pw_default
        pc=  pc_defult
    elif normalizedScore < 0 :
        pw = pw_default
        pc=  pc_default
    elif 0 <= normalizedScore < 0.1 :
        pw = pw_default
        pc = 'red'
    elif 0.1 <= normalizedScore < 0.2:
        pw = normalizedScore
        pc = 'orangered3'
    elif 0.2 <= normalizedScore < 0.3:
        pw =  normalizedScore
        pc = 'orangered2'
    elif 0.3 <= normalizedScore < 0.4:
        pw =  normalizedScore
        pc = 'gold' 
    elif 0.4 <= normalizedScore < 0.5:
        pw =  normalizedScore
        pc = 'chartreuse'
    elif 0.5 <= normalizedScore < 0.6:
        pw =  normalizedScore
        pc = 'limegreen' 
    elif 0.6 <= normalizedScore < 0.7:
        pw =  normalizedScore
        pc = 'lime'
    elif 0.7 <= normalizedScore < 0.8:
        pw =  normalizedScore
        pc = 'cyan3' 
    else:
        pw =  normalizedScore
        pc = 'blue' 

    retlist.extend([pw,pc])
    return retlist

# %%
def add_graph_edge(g, head, tail, zscore=None,
                    penwidth=None,
                    color=None,
                    edgeFontcolor="#40e0d0",
                    edgeFontName = "Ariel",
                    edgeFontSize = "5.0",
                    labelfloat = "false",
                    splines = "true",
                    arrowsize="0.4",
                    weight="3",
                    label_prefix="Zscore = ",
                    zScoreMultiplyer=2,
                    calcColorFn=None):
    """
    Adds a styled edge to the Graphviz graph object `g`.

    Parameters:
        g (Digraph): your graph object
        head (str): source node name
        tail (str): destination node name
        zscore (float): value to encode visually (used to compute penwidth and color)
        penwidth (float or str): overrides computed penwidth if provided
        color (str): overrides computed color if provided
        fontcolor (str): label font color
        fontname (str): label font name
        fontsize (str): label font size
        arrowsize (str): edge arrow size
        weight (str): edge weight
        label_prefix (str): prefix for edge label text
        labelfloat (str): whether label floats with edge curvature
        zScoreMultiplyer (float): multiplier for visual scaling
        calcColorFn (function): function to compute [penwidth, color] from zscore
    """

    # Auto-compute visual attributes if not provided
    if zscore is not None and calcColorFn:
        computed = calcColorFn(zscore)
        pw = penwidth if penwidth is not None else computed[0] * zScoreMultiplyer
        pc = color if color is not None else computed[1]
        label = label_prefix + str(round(computed[0], 2))
    else:
        pw = penwidth or "1.0"
        pc = color or "gray"
        label = ""
    #print(f"\033[92mcreating edge with head:\033[38;5;208m{head}\033[92m -> \033[96m{tail}\033[0m")
    g.edge(str(head), str(tail),
           labelfloat=labelfloat,
           label=label,
           fontsize=edgeFontSize,
           fontcolor=edgeFontcolor,
           fontname=edgeFontName,
           penwidth=str(pw),
           weight=weight,
           arrowsize=arrowsize,
           color=pc)
    
def add_edge_tograph(graph, head_name, tail_name, zscore, color_fn):
    """
    Wrapper for add_graph_edge to simplify synaptic connection additions.

    Parameters:
        graph: Graph object to modify.
        pre_name: Node name representing presynaptic neuron.
        post_name: Node name representing postsynaptic neuron.
        zscore: Z-score value representing synaptic weight.
        color_fn: Function to compute edge color from z-score.

    Returns:
        None
    """
    add_graph_edge(
        g=graph,
        head=head_name,
        tail=tail_name,
        zscore=zscore,
        calcColorFn=color_fn
    )

# %%
# Add Edges to Graph

pw_default = 0.1
pc_default = 'gray'
minNormZscore = 0.03
zScoreMultiplyer = 2

skipped_edges_log = {}
nodeDegreeDict = {}
nodeNameZscoreDict = {}
zScoreMultiplyer = 2
valid_nodes = set()
unique_synapse = set()
unique_legs = set()
unused_legs = set()
orphaned_synapses = set()
skipped_edges_log = {}
unused_legs_log = {}

preSynapse = 'preSynapse'
postSynapse = 'postSynapse'

#Create data type for numpy searches
legDtype = [
    ('connection_type', 'U20'),
    ('head_name', 'U60'),
    ('tail_name', 'U60'),
    ('value', 'f8')
]


for head, tail, data in G.edges(data=True):
    
    
    #print('pre= ' + str(head) + 'post= ' + str(tail))
    head_name = G.nodes(data=True)[head]['uname']
    tail_name = G.nodes(data=True)[tail]['uname']
    valid_nodes.update([head_name])
    valid_nodes.update([tail_name])
    
    #if the head's name contains -- then this is a postsynapse syn->neuron
    if "--" in head_name:
        
        try:
            #IMPORTANT - The NEURONs presynaptic dict is used to get the synapses's postZ
            postZscore = preSynNumberDict[head][2]

            #use the head (postsynapse) as a synapse, the tail as a neuron
            #Note: If it's syn ->neuron, then this is a postsynapse
            unique_legs.add((postSynapse,head_name, tail_name, postZscore))
            unique_synapse.add((head,head_name))

        except (KeyError, TypeError, IndexError) as e:
            skipped_edges_log[f"⚠️MissingData {head}->{tail}"] = (
                f"{head} missing in preSynNumberDict or invalid structure: {repr(e)}"
            )
            continue  # skip and move to the next edge
        
        
        #print(f"Postsynaptic leg added with head hash {head}: {head_name} tail hash {tail}: {tail_name} and zscore= {postZscore} ")
        
    #if the tail's name contains -- then this is a presynapse neuron->syn        
    elif "--" in tail_name:
        
        try:      
        
            #IMPORTANT - The NEURONs postsynaptic dict is used to get the -synapses's- postZ
            preZscore = postSynNumberDict[tail][2]

            #use the head as a synapse, the tail here is a neuron node
            unique_legs.add((preSynapse,head_name, tail_name, preZscore))
            unique_synapse.add((tail,tail_name))
        
        except (KeyError, TypeError, IndexError) as e:
            skipped_edges_log[f"⚠️MissingData {head}->{tail}"] = (
                f"{tail} missing in postSynNumberDict or invalid structure: {repr(e)}"
            )
            continue  # skip and move to the next edge
        
        #print(f"Pretsynaptic leg added with head hash {head}: {head_name} tail hash {tail}: {tail_name} and zscore= {preZscore} ")

    else:
        skipped_edges_log[f"{head}->{tail}"] = f"{head_name} and {tail_name} not found"   

        
#Make an np array of all the synapse legs
synLegs_data = np.array(list(unique_legs), dtype=legDtype)

#Now loop through each unique synapse
for uniqueSynHash, uniqueSynName  in unique_synapse:   

        
    #Get the PRE synaptic LEG
    preSynResult = synLegs_data[
        (synLegs_data['tail_name'] == uniqueSynName ) & 
        (synLegs_data['connection_type'] == preSynapse )
    ]
    
    #if we find data, store the tuple into variables
    if len(preSynResult) == 1:
        preSynConnection, headNamePre, tailNamePre, preZscore = preSynResult[0]
    else:
        skipped_edges_log[f"⚠️Error{uniqueSynHash}-{uniqueSynName}"] = f"Edge for {uniqueSynName} not found" 
        
    
    #Get the POST synaptic LEG
    postSynResult = synLegs_data[
        (synLegs_data['head_name'] == uniqueSynName ) & 
        (synLegs_data['connection_type'] == postSynapse )
    ]

    if len(postSynResult) == 1:
        postSynConnection, headNamePost , tailNamePost, postZscore = postSynResult[0]
    else:
        skipped_edges_log[f"⚠️Error{uniqueSynHash}-{uniqueSynName}"] = f"Edge for {uniqueSynName} not found" 
    
    #we should have two legs here
    #pdb.set_trace()
    
    
    #We only want to process associated pre and post legs if they fall below the min
    if  preZscore >= minNormZscore and postZscore >= minNormZscore: 
    
        pdb.set_trace()
        #Add pre and post legs 
        add_edge_tograph(g, headNamePre, tailNamePre, preZscore, calcColor)
        add_edge_tograph(g, headNamePost, tailNamePost, postZscore, calcColor)

    else:
        
        
        #save the unused legs for.. reasons
        unused_legs.add((preSynConnection,headNamePre, tailNamePre,preZscore))
        unused_legs.add((postSynConnection,headNamePost, tailNamePost,postZscore))
        unused_legs_log[f"{headNamePre}->{tailNamePre}"] = f"Ignore leg with preZ={preZscore} and postZ={postZscore}"
        
        # Use the pre tailname to note which syanaptic nodes can be removed
        orphaned_synapses.add(tailNamePre)
        
        
print(f"⚠️ Error with {len(skipped_edges_log)} edges not found! ")
display(JSON(skipped_edges_log, expanded=False))
print(f"⚠️ [INFO] {len(unused_legs_log)} edges unused due to low Z-scores")
display(JSON(unused_legs_log, expanded=False))

print( f"number of legs: {len(unique_legs)}" )
# print(f" Valid legs: {unique_legs}")


print(f"number of G nodes: {len(G.nodes())}")
print(f"number of valid_nodes nodes: {len(valid_nodes)}")
# Out:
# None
# > /tmp/ipykernel_649/1349993453.py(126)<module>()
#     124         pdb.set_trace()
#     125         #Add pre and post legs
# --> 126         add_edge_tograph(g, headNamePre, tailNamePre, preZscore, calcColor)
#     127         add_edge_tograph(g, headNamePost, tailNamePost, postZscore, calcColor)
#     128
# ipdb>  c
# > /tmp/ipykernel_649/4227141341.py(47)add_graph_edge()
#      45     #print(f"\033creating edge with head:\033{head}\033 -> \033{tail}\033")
#      46     pdb.set_trace()
# ---> 47     g.edge(str(head), str(tail),
#      48            labelfloat=labelfloat,
#      49            label=label,
# ipdb>  str(head)
# 'LHPV5e1_R_1'
# ipdb>  str(tail)
# 'LHPV5e1_R_1--SIP090(SCB027)_R_1'
# ipdb>  q

# %%
#Add nodes to Graph

synaptic_node_log = {}         # for nodes with '--'
non_synaptic_node_log = {}     # for others
node_centrality = {}
sizeMultiplyer = 2
nodeFontSize = "5"

#NODE Attributtes

#macro for name to id conversion
uname_to_id = {G.nodes[n]['uname']: n for n in G.nodes()}




for _node in valid_nodes:
    # if "FB1A_R_2--FB1E_a_R_2" == str(_node):
    #     pdb.set_trace()
    
    if _node in orphaned_synapses:
        #print(f'Node {str(_node)} will not be rendered.')
        continue  # skip disconnected synapse
    
    #Check that this is a synapse
    if '--' in str(_node):
        # centrality_val = node_centrality.get(str(_node))
        raw_id = uname_to_id.get(_node)
        ht = 0.05

        g.node(str(_node),
               shape='circle',
               height=str(ht),
               label='',
               fontsize='5.0',
               fontcolor='orange',
               fixedsize='true',
               color='cyan',
               style='filled')
        
        synaptic_node_log[str(_node)] = {
            "centrality": "NA",
            "status": "rendered" }

    else:
        # if '--' not in str(_node) and it must be a neuron:
        raw_id = uname_to_id.get(_node)
        centrality_val = G.nodes.get(raw_id, {}).get('centrality', 0.0)
        
        centrality2height = centrality_val * sizeMultiplyer
        
        if centrality2height is None:
            print(f"⚠️ Missing centrality for node {_node}")
            centrality2height = 0.0  # fallback value
        
        ht = centrality2height if centrality2height > 0.05 else 0.05
        ht = round(ht, 1)
        centralityLabel = "cent= " + str(ht)
        
        g.node(str(_node),
            shape='circle',
            height= str(ht),
            fontsize=nodeFontSize,
            label= str(_node +"\n" + centralityLabel),
            fixedsize='true',
            fontcolor='white',
            color='brown2',
            style='filled')

        synaptic_node_log[str(_node)] = {
            "centrality": centrality2height
        }

# %%
if os.path.exists("G_auto.svg"):
    os.remove("G_auto.svg")

# %%
g.attr(size='50,50')
g.verbose = True
try:
    g.save('G_auto.gv')
    g.render('G_auto', format = 'svg', view=False)
    
#g.render('G_auto', format = 'png', view=False)
except Exception as e:
    self.raise_error(e, 'There was an error during diagram generation. Please execute "conda install -c anaconda graphviz" in your terminal in your conda environment, or try to install GraphViz globally from https://graphviz.org/download/.')


#Make a filter str to use in the save file name
nFilterStr = nFilter.replace('$','')

characters_to_replace = ['/r', ']', '[', '.', '*', '(', ')']

# Replace each character in the list
for char in characters_to_replace:
    nFilterStr = nFilterStr.replace(char, '')


noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')
shutil.copy('G_auto.svg', noiFileName + '.svg')
# Out:
# Warning: node 'LHPV5e1_R_1', graph 'G' size too small for label
# Warning: node 'SIP090(SCB027)_R_1', graph 'G' size too small for label
# Warning: node 'SMP177_R_1', graph 'G' size too small for label
# Warning: node 'MBON13(a'2)_R_1', graph 'G' size too small for label
# Warning: node 'CRE055_R_7', graph 'G' size too small for label
# Warning: node 'SMP127_R_1', graph 'G' size too small for label
# Warning: node 'FB5AB_R_1', graph 'G' size too small for label
# Warning: node 'CRE077_R_1', graph 'G' size too small for label
# Warning: node 'LHCENT4_R_1', graph 'G' size too small for label
# Warning: node 'LHPV10d1_R_1', graph 'G' size too small for label
# Warning: node 'LHCENT11_R_1', graph 'G' size too small for label
# Warning: Illegal value sgd for attribute "mode" in graph G - ignored
# Warning: transparent is not a known color.
# 'MBON13__75post_001.svg'

# %%
with open('G_auto.svg', 'r') as file:
    data = file.read()

# %%
# Update widgets and widget managers throughout the frontend (included for compatibility)
for i in fbl.widget_manager.widgets:
    if fbl.widget_manager.widgets[i].widget_id not in fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets']:
        fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets'].append(fbl.widget_manager.widgets[i].widget_id)

# Load the diagram
my_client.tryComms({'widget':'GFX', 
                    'messageType': 'loadCircuitFromString', 
                    'data': {'string':data, 'name':'custom'}})

# Run the submodule called onGraphVizLoad2 to make the diagram interactive
my_client.tryComms({'widget':'GFX', 
                    'messageType': 'eval', 
                    'data': {'data':"window.fbl.loadSubmodule('data/FBLSubmodules/onGraphVizLoad2.js');", 'name':'custom'}})

# %%
#Write data out to files:

from collections import defaultdict

# Input and suffix base
input_file = 'G_auto.gv'
#noiFileName = 'neuronX'  # Already set at the start of notebook

# Read original lines
with open(input_file, 'r') as file:
    lines = file.readlines()
    oglines = lines[:]

# Step 1: Clean patterns
patterns = ['_[RL]', '_\d', '_C\d']
replacement_texts = ['', '', '']
for i in range(len(patterns)):
    lines = [re.sub(patterns[i], replacement_texts[i], line) for line in lines]

# Write cleaned file
with open(noiFileName + '.gv', 'w') as postProcessfile:
    postProcessfile.writelines(lines)

# Write original file
with open(noiFileName + '_all.gv', 'w') as postProcessfile:
    postProcessfile.writelines(oglines)

# Regex to capture edge tail, head, and Zscore value
edge_pattern = re.compile(
    r'"([^"]+)"\s*->\s*"([^"]+)"\s*\[.*?label\s*=\s*"Zscore\s*=\s*(\-?\d+\.\d+)"')

edge_dict = defaultdict(list)
other_lines = []

for line in lines:
    match = edge_pattern.search(line)
    if match:
        tail, head, zscore = match.groups()
        edge_key = (tail, head)
        edge_dict[edge_key].append((float(zscore), line))
    else:
        other_lines.append(line)


# Remove any premature closing brace from other_lines
other_lines = [line for line in other_lines if line.strip() != '}']
        
    

# Collect retained and removed edges
retained_edges = []
removed_edges = []

for edge_key, edge_list in edge_dict.items():
    best_edge = max(edge_list, key=lambda x: x[0])
    retained_edges.append(best_edge[1])
    removed_edges.extend(e[1] for e in edge_list if e != best_edge)

    
# Write filtered + retained file
with open(noiFileName + '_002.gv', 'w') as f:
    f.writelines(other_lines + retained_edges)
    f.write('\tsize="50,50"\n')
    f.write('}')

# Optional: write removed edges separately for auditing
with open(noiFileName + '_removed.gv', 'w') as f:
    f.write('digraph G {\n')
    f.writelines(removed_edges)
    f.write('\tsize="50,50"\n')
    f.write('}')
# Out:
# > /tmp/ipykernel_649/3212404883.py(35)<module>()
#      33 other_lines = []
#      34
# ---> 35 for line in lines:
#      36     match = edge_pattern.search(line)
#      37     if match:
# ipdb>  line
# '\t"LHPV5e1--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5228287445519295 weight=3]\n'
# ipdb>  q

# %% [markdown]
# # Merge Data

# %%
import warnings

def clean_node_id(node_str):
    return node_str.strip('"').strip()

def parse_edge_line(line):
    pattern = r'\"?([^\s\"]+)\"?\s*->\s*\"?([^\s\"]+)\"?.*?label=\"Zscore\s*=\s*([-+]?[0-9]*\.?[0-9]+)\"'
    match = re.search(pattern, line.strip())
    if match:
        head, tail, z_score = match.groups()
        return head.strip('"'), tail.strip('"'), float(z_score), line.strip()
    return None


def merge_graph_files(directory='merge_graphs', output_file='merged_data.gv'):
    if not os.path.exists(directory):
        os.makedirs(directory)
        warnings.warn("Directory 'merge_graphs' not found. Created empty directory. Halting routine.")
        return

    merged_edges = []
    graph_header = []

    for filename in os.listdir(directory):
        if filename.endswith('.gv') and not filename.startswith('merged') and not filename.startswith('unused'):
            with open(os.path.join(directory, filename), 'r') as f:
                lines = f.readlines()

            if not graph_header:
                graph_header = lines[:2]

            body_lines = []  # 🔄 Reset for each file
            layout_directives = ('size=', 'rotation=', 'splines=')

            for line in lines[2:]:
                stripped = line.strip()
                if stripped == '}':
                    continue
                # Only skip lines that *start* with layout directives
                if any(stripped.startswith(directive) for directive in layout_directives):
                    print(f"Skipping layout directive line: {stripped}")
                    continue
                body_lines.append(line)

                
            merged_edges.extend(body_lines)
            print(f"{len(body_lines)} lines of file {filename} merged. Total lines in merged now equals: {len(merged_edges)}")

    # Deduplicate after all files are processed
    edge_dict = {}
    unused_edges = {}
    node_buffer = []
    node_set = set()

    for line in merged_edges:
        parsed = parse_edge_line(line)

        if parsed:
            #print(f"Parsed result: --{parsed}--, Line = {line}")
            parsed_head, parsed_tail, z, full_line = parsed
            key = (parsed_head, parsed_tail)

            # Filtering logic: keep only highest Z-score
            if key not in edge_dict or z > edge_dict[key][0]:
                edge_dict[key] = (z, full_line)
            else:
                # Log discarded edge
                unused_edges.setdefault(key, []).append((z, full_line))
        else:
            # Node handling logic (as discussed earlier)
            line = line.strip()
            if not line:
                continue
            node_buffer.append(line)
            if line.endswith(']'):
                full_node = ' '.join(node_buffer)
                node_set.add(full_node)
                node_buffer = []
                #print(f"Parsed Node found: {full_node}")



                
    output_path_merged = os.path.join(directory, output_file)

    #pdb.set_trace()
    #Write out data to merged file
    with open(output_path_merged, 'w') as out:
        out.writelines(graph_header)
        # Write unique nodes
        for node_line in sorted(node_set):
            out.write(node_line + '\n')
        # Write edges
        for _, (_, line) in edge_dict.items():
            out.write(line + '\n')
        out.write('\tsize="50,50"\n')
        out.write('}\n')

    print(f"✅ Merged graph written to {output_file} with {len(edge_dict)} unique edges.")

    output_path_log = os.path.join(directory, 'unused_log.gv')
    
    with open(output_path_log, 'w') as f:
        for key, entries in unused_edges.items():
            for z_val, line_text in entries:
                f.write(f"# Discarded [{key[0]} -> {key[1]}] with z={z_val}: {line_text}\n")
    print(f"✅ Unused itmes log written to {output_path_log} with {len(unused_edges)}  items.")

merge_graph_files()
# Out:
# Skipping layout directive line: size="50,50"
# Skipping layout directive line: size="50,50"
# 159 lines of file MBON13__75post_001_002.gv merged. Total lines in merged now equals: 159
# Skipping layout directive line: size="50,50"
# Skipping layout directive line: size="50,50"
# 74 lines of file MBON13__50pre_001_002.gv merged. Total lines in merged now equals: 233
# Parsed result: --('LHPV5e1', 'LHPV5e1--SIP090(SCB027)', 0.53, 'LHPV5e1 -> "LHPV5e1--SIP090(SCB027)" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0587119560477893 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--SIP090(SCB027)" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0587119560477893 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--SMP177', 0.36, 'SIP087 -> "SIP087--SMP177" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7245941864854659 weight=3]')--, Line = 	SIP087 -> "SIP087--SMP177" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7245941864854659 weight=3]
#
# Parsed result: --('SIP087--SMP177', 'SMP177', 0.1, '"SIP087--SMP177" -> SMP177 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--SMP177" -> SMP177 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("MBON13(a'2)--CRE055", 'CRE055', 1.0, '"MBON13(a\'2)--CRE055" -> CRE055 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"MBON13(a'2)--CRE055" -> CRE055 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("MBON13(a'2)--SMP127", 'SMP127', 1.0, '"MBON13(a\'2)--SMP127" -> SMP127 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"MBON13(a'2)--SMP127" -> SMP127 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --('SMP177', 'SMP177--CRE055', 0.1, 'SMP177 -> "SMP177--CRE055" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	SMP177 -> "SMP177--CRE055" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SMP177--CRE055', 'CRE055', 0.25, '"SMP177--CRE055" -> CRE055 [label="Zscore = 0.25" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.49870466321243523 weight=3]')--, Line = 	"SMP177--CRE055" -> CRE055 [label="Zscore = 0.25" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.49870466321243523 weight=3]
#
# Parsed result: --('LHPV5e1', 'LHPV5e1--FB5AB', 0.64, 'LHPV5e1 -> "LHPV5e1--FB5AB" [label="Zscore = 0.64" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2811982209819481 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--FB5AB" [label="Zscore = 0.64" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2811982209819481 weight=3]
#
# Parsed result: --('LHPV5e1--FB5AB', 'FB5AB', 0.34, '"LHPV5e1--FB5AB" -> FB5AB [label="Zscore = 0.34" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6817355212768232 weight=3]')--, Line = 	"LHPV5e1--FB5AB" -> FB5AB [label="Zscore = 0.34" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6817355212768232 weight=3]
#
# Parsed result: --('CRE077', 'CRE077--LHCENT4', 0.1, 'CRE077 -> "CRE077--LHCENT4" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	CRE077 -> "CRE077--LHCENT4" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('CRE077--LHCENT4', 'LHCENT4', 0.11, '"CRE077--LHCENT4" -> LHCENT4 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2232544636376832 weight=3]')--, Line = 	"CRE077--LHCENT4" -> LHCENT4 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2232544636376832 weight=3]
#
# Parsed result: --("MBON13(a'2)--LHPV10d1", 'LHPV10d1', 0.37, '"MBON13(a\'2)--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.37" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7309442497093994 weight=3]')--, Line = 	"MBON13(a'2)--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.37" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7309442497093994 weight=3]
#
# Parsed result: --('SIP090(SCB027)--SIP087', 'SIP087', 0.1, '"SIP090(SCB027)--SIP087" -> SIP087 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP090(SCB027)--SIP087" -> SIP087 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('LHPV10d1', 'LHPV10d1--SMP177', 0.24, 'LHPV10d1 -> "LHPV10d1--SMP177" [label="Zscore = 0.24" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4796827642603567 weight=3]')--, Line = 	LHPV10d1 -> "LHPV10d1--SMP177" [label="Zscore = 0.24" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4796827642603567 weight=3]
#
# Parsed result: --('LHPV10d1--SMP177', 'SMP177', 0.17, '"LHPV10d1--SMP177" -> SMP177 [label="Zscore = 0.17" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.348462019807241 weight=3]')--, Line = 	"LHPV10d1--SMP177" -> SMP177 [label="Zscore = 0.17" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.348462019807241 weight=3]
#
# Parsed result: --('CRE055', "CRE055--MBON13(a'2)", 1.0, 'CRE055 -> "CRE055--MBON13(a\'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	CRE055 -> "CRE055--MBON13(a'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("MBON13(a'2)--LHCENT11", 'LHCENT11', 0.83, '"MBON13(a\'2)--LHCENT11" -> LHCENT11 [label="Zscore = 0.83" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.6613544077195126 weight=3]')--, Line = 	"MBON13(a'2)--LHCENT11" -> LHCENT11 [label="Zscore = 0.83" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.6613544077195126 weight=3]
#
# Parsed result: --('LHPV10d1', 'LHPV10d1--CRE077', 0.26, 'LHPV10d1 -> "LHPV10d1--CRE077" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5266061357338023 weight=3]')--, Line = 	LHPV10d1 -> "LHPV10d1--CRE077" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5266061357338023 weight=3]
#
# Parsed result: --('LHPV10d1--CRE077', 'CRE077', 0.23, '"LHPV10d1--CRE077" -> CRE077 [label="Zscore = 0.23" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.46415515050947653 weight=3]')--, Line = 	"LHPV10d1--CRE077" -> CRE077 [label="Zscore = 0.23" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.46415515050947653 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--CRE077', 0.28, 'SIP087 -> "SIP087--CRE077" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5684220460551153 weight=3]')--, Line = 	SIP087 -> "SIP087--CRE077" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5684220460551153 weight=3]
#
# Parsed result: --('SIP087--CRE077', 'CRE077', 0.1, '"SIP087--CRE077" -> CRE077 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--CRE077" -> CRE077 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('LHPV5e1', 'LHPV5e1--CRE055', 0.17, 'LHPV5e1 -> "LHPV5e1--CRE055" [label="Zscore = 0.17" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.33991017702973747 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--CRE055" [label="Zscore = 0.17" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.33991017702973747 weight=3]
#
# Parsed result: --('LHPV5e1--CRE055', 'CRE055', 0.26, '"LHPV5e1--CRE055" -> CRE055 [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5132067684688402 weight=3]')--, Line = 	"LHPV5e1--CRE055" -> CRE055 [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5132067684688402 weight=3]
#
# Parsed result: --('CRE055', 'CRE055--LHCENT4', 0.43, 'CRE055 -> "CRE055--LHCENT4" [label="Zscore = 0.43" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.8690210102816271 weight=3]')--, Line = 	CRE055 -> "CRE055--LHCENT4" [label="Zscore = 0.43" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.8690210102816271 weight=3]
#
# Parsed result: --('CRE055--LHCENT4', 'LHCENT4', 0.1, '"CRE055--LHCENT4" -> LHCENT4 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"CRE055--LHCENT4" -> LHCENT4 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('CRE055', "CRE055--MBON13(a'2)", 0.74, 'CRE055 -> "CRE055--MBON13(a\'2)" [label="Zscore = 0.74" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4722098047980927 weight=3]')--, Line = 	CRE055 -> "CRE055--MBON13(a'2)" [label="Zscore = 0.74" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4722098047980927 weight=3]
#
# Parsed result: --('LHCENT11', 'LHCENT11--LHCENT4', 0.1, 'LHCENT11 -> "LHCENT11--LHCENT4" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	LHCENT11 -> "LHCENT11--LHCENT4" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('LHCENT11--LHCENT4', 'LHCENT4', 0.1, '"LHCENT11--LHCENT4" -> LHCENT4 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"LHCENT11--LHCENT4" -> LHCENT4 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SMP177', 'SMP177--SIP087', 0.24, 'SMP177 -> "SMP177--SIP087" [label="Zscore = 0.24" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.48953089725020615 weight=3]')--, Line = 	SMP177 -> "SMP177--SIP087" [label="Zscore = 0.24" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.48953089725020615 weight=3]
#
# Parsed result: --('SMP177--SIP087', 'SIP087', 0.45, '"SMP177--SIP087" -> SIP087 [label="Zscore = 0.45" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9037891292076625 weight=3]')--, Line = 	"SMP177--SIP087" -> SIP087 [label="Zscore = 0.45" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9037891292076625 weight=3]
#
# Parsed result: --('SMP177', 'SMP177--CRE055', 0.1, 'SMP177 -> "SMP177--CRE055" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	SMP177 -> "SMP177--CRE055" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SMP177--CRE055', 'CRE055', 0.39, '"SMP177--CRE055" -> CRE055 [label="Zscore = 0.39" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7835328105654147 weight=3]')--, Line = 	"SMP177--CRE055" -> CRE055 [label="Zscore = 0.39" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7835328105654147 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--SIP090(SCB027)', 0.27, 'SIP087 -> "SIP087--SIP090(SCB027)" [label="Zscore = 0.27" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.54239335598339 weight=3]')--, Line = 	SIP087 -> "SIP087--SIP090(SCB027)" [label="Zscore = 0.27" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.54239335598339 weight=3]
#
# Parsed result: --('LHPV10d1', 'LHPV10d1--FB5AB', 0.21, 'LHPV10d1 -> "LHPV10d1--FB5AB" [label="Zscore = 0.21" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4233747184922214 weight=3]')--, Line = 	LHPV10d1 -> "LHPV10d1--FB5AB" [label="Zscore = 0.21" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4233747184922214 weight=3]
#
# Parsed result: --('LHPV10d1--FB5AB', 'FB5AB', 0.2, '"LHPV10d1--FB5AB" -> FB5AB [label="Zscore = 0.2" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4012537172931687 weight=3]')--, Line = 	"LHPV10d1--FB5AB" -> FB5AB [label="Zscore = 0.2" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4012537172931687 weight=3]
#
# Parsed result: --('LHPV5e1', 'LHPV5e1--CRE055', 0.27, 'LHPV5e1 -> "LHPV5e1--CRE055" [label="Zscore = 0.27" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5452821138920381 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--CRE055" [label="Zscore = 0.27" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5452821138920381 weight=3]
#
# Parsed result: --('LHPV5e1--CRE055', 'CRE055', 0.38, '"LHPV5e1--CRE055" -> CRE055 [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7694300518134713 weight=3]')--, Line = 	"LHPV5e1--CRE055" -> CRE055 [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7694300518134713 weight=3]
#
# Parsed result: --('SIP090(SCB027)--FB5AB', 'FB5AB', 0.22, '"SIP090(SCB027)--FB5AB" -> FB5AB [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4386512911576559 weight=3]')--, Line = 	"SIP090(SCB027)--FB5AB" -> FB5AB [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4386512911576559 weight=3]
#
# Parsed result: --('CRE055', 'CRE055--LHCENT4', 0.72, 'CRE055 -> "CRE055--LHCENT4" [label="Zscore = 0.72" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4399255939798765 weight=3]')--, Line = 	CRE055 -> "CRE055--LHCENT4" [label="Zscore = 0.72" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4399255939798765 weight=3]
#
# Parsed result: --('CRE055--LHCENT4', 'LHCENT4', 0.14, '"CRE055--LHCENT4" -> LHCENT4 [label="Zscore = 0.14" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.27260850631441436 weight=3]')--, Line = 	"CRE055--LHCENT4" -> LHCENT4 [label="Zscore = 0.14" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.27260850631441436 weight=3]
#
# Parsed result: --("MBON13(a'2)--FB5AB", 'FB5AB', 0.6, '"MBON13(a\'2)--FB5AB" -> FB5AB [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2053015553796453 weight=3]')--, Line = 	"MBON13(a'2)--FB5AB" -> FB5AB [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2053015553796453 weight=3]
#
# Parsed result: --("MBON13(a'2)--SMP177", 'SMP177', 0.29, '"MBON13(a\'2)--SMP177" -> SMP177 [label="Zscore = 0.29" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5733193034954571 weight=3]')--, Line = 	"MBON13(a'2)--SMP177" -> SMP177 [label="Zscore = 0.29" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5733193034954571 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--SMP127', 0.1, 'SIP087 -> "SIP087--SMP127" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	SIP087 -> "SIP087--SMP127" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SIP087--SMP127', 'SMP127', 0.1, '"SIP087--SMP127" -> SMP127 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--SMP127" -> SMP127 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--LHCENT11', 0.19, 'SIP087 -> "SIP087--LHCENT11" [label="Zscore = 0.19" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3862212155530389 weight=3]')--, Line = 	SIP087 -> "SIP087--LHCENT11" [label="Zscore = 0.19" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3862212155530389 weight=3]
#
# Parsed result: --('SIP087--LHCENT11', 'LHCENT11', 0.11, '"SIP087--LHCENT11" -> LHCENT11 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.22614213567363817 weight=3]')--, Line = 	"SIP087--LHCENT11" -> LHCENT11 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.22614213567363817 weight=3]
#
# Parsed result: --('CRE055', 'CRE055--LHPV5e1', 0.28, 'CRE055 -> "CRE055--LHPV5e1" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5531411177813477 weight=3]')--, Line = 	CRE055 -> "CRE055--LHPV5e1" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5531411177813477 weight=3]
#
# Parsed result: --('CRE055--LHPV5e1', 'LHPV5e1', 0.1, '"CRE055--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"CRE055--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("MBON13(a'2)--CRE055", 'CRE055', 1.0, '"MBON13(a\'2)--CRE055" -> CRE055 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"MBON13(a'2)--CRE055" -> CRE055 [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --('LHPV10d1', 'LHPV10d1--LHPV5e1', 0.12, 'LHPV10d1 -> "LHPV10d1--LHPV5e1" [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.24506590689312757 weight=3]')--, Line = 	LHPV10d1 -> "LHPV10d1--LHPV5e1" [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.24506590689312757 weight=3]
#
# Parsed result: --('LHPV10d1--LHPV5e1', 'LHPV5e1', 0.1, '"LHPV10d1--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2059797762133908 weight=3]')--, Line = 	"LHPV10d1--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2059797762133908 weight=3]
#
# Parsed result: --('SMP177', 'SMP177--LHPV10d1', 0.1, 'SMP177 -> "SMP177--LHPV10d1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	SMP177 -> "SMP177--LHPV10d1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SMP177--LHPV10d1', 'LHPV10d1', 0.18, '"SMP177--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.18" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3604170233471802 weight=3]')--, Line = 	"SMP177--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.18" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3604170233471802 weight=3]
#
# Parsed result: --('LHPV5e1', 'LHPV5e1--CRE077', 0.46, 'LHPV5e1 -> "LHPV5e1--CRE077" [label="Zscore = 0.46" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9217973314729224 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--CRE077" [label="Zscore = 0.46" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9217973314729224 weight=3]
#
# Parsed result: --('LHPV5e1--CRE077', 'CRE077', 0.22, '"LHPV5e1--CRE077" -> CRE077 [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.44680097141918806 weight=3]')--, Line = 	"LHPV5e1--CRE077" -> CRE077 [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.44680097141918806 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--FB5AB', 0.18, 'SIP087 -> "SIP087--FB5AB" [label="Zscore = 0.18" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.36019252548131364 weight=3]')--, Line = 	SIP087 -> "SIP087--FB5AB" [label="Zscore = 0.18" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.36019252548131364 weight=3]
#
# Parsed result: --('SIP087--FB5AB', 'FB5AB', 0.1, '"SIP087--FB5AB" -> FB5AB [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--FB5AB" -> FB5AB [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("MBON13(a'2)--SIP087", 'SIP087', 0.44, '"MBON13(a\'2)--SIP087" -> SIP087 [label="Zscore = 0.44" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.8760369552635527 weight=3]')--, Line = 	"MBON13(a'2)--SIP087" -> SIP087 [label="Zscore = 0.44" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.8760369552635527 weight=3]
#
# Parsed result: --('CRE055', 'CRE055--LHPV5e1', 0.28, 'CRE055 -> "CRE055--LHPV5e1" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5674266130233945 weight=3]')--, Line = 	CRE055 -> "CRE055--LHPV5e1" [label="Zscore = 0.28" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5674266130233945 weight=3]
#
# Parsed result: --('CRE055--LHPV5e1', 'LHPV5e1', 0.1, '"CRE055--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"CRE055--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("MBON13(a'2)--LHCENT4", 'LHCENT4', 0.57, '"MBON13(a\'2)--LHCENT4" -> LHCENT4 [label="Zscore = 0.57" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.1412396574248804 weight=3]')--, Line = 	"MBON13(a'2)--LHCENT4" -> LHCENT4 [label="Zscore = 0.57" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.1412396574248804 weight=3]
#
# Parsed result: --("MBON13(a'2)--CRE077", 'CRE077', 0.47, '"MBON13(a\'2)--CRE077" -> CRE077 [label="Zscore = 0.47" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9327179859472634 weight=3]')--, Line = 	"MBON13(a'2)--CRE077" -> CRE077 [label="Zscore = 0.47" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9327179859472634 weight=3]
#
# Parsed result: --('LHPV5e1', 'LHPV5e1--SIP087', 0.55, 'LHPV5e1 -> "LHPV5e1--SIP087" [label="Zscore = 0.55" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0929406121915062 weight=3]')--, Line = 	LHPV5e1 -> "LHPV5e1--SIP087" [label="Zscore = 0.55" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0929406121915062 weight=3]
#
# Parsed result: --('LHPV5e1--SIP087', 'SIP087', 0.21, '"LHPV5e1--SIP087" -> SIP087 [label="Zscore = 0.21" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.41118804169971357 weight=3]')--, Line = 	"LHPV5e1--SIP087" -> SIP087 [label="Zscore = 0.21" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.41118804169971357 weight=3]
#
# Parsed result: --("MBON13(a'2)--LHPV5e1", 'LHPV5e1', 0.93, '"MBON13(a\'2)--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.93" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.8504983146844491 weight=3]')--, Line = 	"MBON13(a'2)--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.93" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.8504983146844491 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--LHPV5e1', 0.38, 'SIP087 -> "SIP087--LHPV5e1" [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7506228765571916 weight=3]')--, Line = 	SIP087 -> "SIP087--LHPV5e1" [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7506228765571916 weight=3]
#
# Parsed result: --('SIP087--LHPV5e1', 'LHPV5e1', 0.11, '"SIP087--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.22356820977992609 weight=3]')--, Line = 	"SIP087--LHPV5e1" -> LHPV5e1 [label="Zscore = 0.11" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.22356820977992609 weight=3]
#
# Parsed result: --('SIP087', 'SIP087--LHPV10d1', 0.22, 'SIP087 -> "SIP087--LHPV10d1" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4382785956964892 weight=3]')--, Line = 	SIP087 -> "SIP087--LHPV10d1" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4382785956964892 weight=3]
#
# Parsed result: --('SIP087--LHPV10d1', 'LHPV10d1', 0.1, '"SIP087--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--LHPV10d1" -> LHPV10d1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('CRE077', 'CRE077--SMP177', 0.1, 'CRE077 -> "CRE077--SMP177" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	CRE077 -> "CRE077--SMP177" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('CRE077--SMP177', 'SMP177', 0.1, '"CRE077--SMP177" -> SMP177 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"CRE077--SMP177" -> SMP177 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed Node found: "SIP090(SCB027)--FB5AB" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--SIP087" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--LHPV10d1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: LHPV10d1 [label="LHPV10d1 cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "CRE077--SMP177" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: LHCENT4 [label="LHCENT4 cent= 0.2" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.2 shape=circle style=filled]
# Parsed Node found: SIP087 [label="SIP087 cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--SMP177" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: CRE055 [label="CRE055 cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "SIP087--SIP090(SCB027)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE055--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--LHPV5e1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: FB5AB [label="FB5AB cent= 0.2" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.2 shape=circle style=filled]
# Parsed Node found: "LHPV10d1--SMP177" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SMP177--SIP087" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--FB5AB" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV10d1--FB5AB" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE055--LHCENT4" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE055--LHPV5e1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--CRE077" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE077--LHCENT4" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--LHCENT4" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--CRE077" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV10d1--LHPV5e1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE055--LHPV5e1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--CRE077" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--SMP127" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: CRE077 [label="CRE077 cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "SMP177--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: LHPV5e1 [label="LHPV5e1 cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--SMP127" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP090(SCB027)" [label="SIP090(SCB027) cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--FB5AB" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--LHCENT11" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--LHCENT11" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SMP177--LHPV10d1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV10d1--CRE077" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--SMP177" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "CRE055--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--SIP090(SCB027)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: CRE055 [label="CRE055 cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: SMP127 [label="SMP127 cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "SMP177--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHCENT11--LHCENT4" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)" [label="MBON13(a'2) cent= 0.4" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.4 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--CRE055" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--LHPV5e1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP087--FB5AB" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--SIP090(SCB027)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "SIP090(SCB027)--SIP087" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)--LHPV10d1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHPV5e1--SIP087" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: SMP177 [label="SMP177 cent= 0.4" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.4 shape=circle style=filled]
# Parsed Node found: "CRE055--LHCENT4" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: LHCENT11 [label="LHCENT11 cent= 0.2" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.2 shape=circle style=filled]
# Parsed result: --('LHPV5e1--SIP090(SCB027)', 'SIP090(SCB027)', 0.26, '"LHPV5e1--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5228287445519295 weight=3]')--, Line = 	"LHPV5e1--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5228287445519295 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--CRE055", 0.36, '"MBON13(a\'2)" -> "MBON13(a\'2)--CRE055" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7292431850428165 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--CRE055" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7292431850428165 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--SMP127", 0.38, '"MBON13(a\'2)" -> "MBON13(a\'2)--SMP127" [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7583444861487063 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--SMP127" [label="Zscore = 0.38" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7583444861487063 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--SIP090(SCB027)", 0.63, '"MBON13(a\'2)" -> "MBON13(a\'2)--SIP090(SCB027)" [label="Zscore = 0.63" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2627670386507943 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--SIP090(SCB027)" [label="Zscore = 0.63" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2627670386507943 weight=3]
#
# Parsed result: --("MBON13(a'2)--SIP090(SCB027)", 'SIP090(SCB027)', 0.6, '"MBON13(a\'2)--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2025087700648454 weight=3]')--, Line = 	"MBON13(a'2)--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2025087700648454 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--LHPV10d1", 0.37, '"MBON13(a\'2)" -> "MBON13(a\'2)--LHPV10d1" [label="Zscore = 0.37" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7389436187447798 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--LHPV10d1" [label="Zscore = 0.37" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7389436187447798 weight=3]
#
# Parsed result: --('SIP090(SCB027)', 'SIP090(SCB027)--SIP087', 0.32, '"SIP090(SCB027)" -> "SIP090(SCB027)--SIP087" [label="Zscore = 0.32" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6381222594789786 weight=3]')--, Line = 	"SIP090(SCB027)" -> "SIP090(SCB027)--SIP087" [label="Zscore = 0.32" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6381222594789786 weight=3]
#
# Parsed result: --("CRE055--MBON13(a'2)", "MBON13(a'2)", 0.1, '"CRE055--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"CRE055--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--LHCENT11", 0.47, '"MBON13(a\'2)" -> "MBON13(a\'2)--LHCENT11" [label="Zscore = 0.47" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9329522927840443 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--LHCENT11" [label="Zscore = 0.47" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9329522927840443 weight=3]
#
# Parsed result: --('SIP087--SIP090(SCB027)', 'SIP090(SCB027)', 0.1, '"SIP087--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"SIP087--SIP090(SCB027)" -> "SIP090(SCB027)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('SIP090(SCB027)', 'SIP090(SCB027)--FB5AB', 0.49, '"SIP090(SCB027)" -> "SIP090(SCB027)--FB5AB" [label="Zscore = 0.49" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9889089502192416 weight=3]')--, Line = 	"SIP090(SCB027)" -> "SIP090(SCB027)--FB5AB" [label="Zscore = 0.49" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9889089502192416 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--FB5AB", 0.6, '"MBON13(a\'2)" -> "MBON13(a\'2)--FB5AB" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2045644364390147 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--FB5AB" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2045644364390147 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--SMP177", 0.35, '"MBON13(a\'2)" -> "MBON13(a\'2)--SMP177" [label="Zscore = 0.35" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7098423176388902 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--SMP177" [label="Zscore = 0.35" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7098423176388902 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--SIP087", 0.6, '"MBON13(a\'2)" -> "MBON13(a\'2)--SIP087" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2045644364390147 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--SIP087" [label="Zscore = 0.6" arrowsize=0.4 color=lime fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.2045644364390147 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--LHCENT4", 0.53, '"MBON13(a\'2)" -> "MBON13(a\'2)--LHCENT4" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0687583646115297 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--LHCENT4" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.0687583646115297 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--CRE077", 0.5, '"MBON13(a\'2)" -> "MBON13(a\'2)--CRE077" [label="Zscore = 0.5" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.000855328697787 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--CRE077" [label="Zscore = 0.5" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.000855328697787 weight=3]
#
# Parsed result: --("MBON13(a'2)", "MBON13(a'2)--LHPV5e1", 1.0, '"MBON13(a\'2)" -> "MBON13(a\'2)--LHPV5e1" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"MBON13(a'2)" -> "MBON13(a'2)--LHPV5e1" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("PPL105(a'2a2)--APL", 'APL', 0.1, '"PPL105(a\'2a2)--APL" -> APL [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"PPL105(a'2a2)--APL" -> APL [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("PPL105(a'2a2)--DPM", 'DPM', 0.2, '"PPL105(a\'2a2)--DPM" -> DPM [label="Zscore = 0.2" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3916530543611423 weight=3]')--, Line = 	"PPL105(a'2a2)--DPM" -> DPM [label="Zscore = 0.2" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3916530543611423 weight=3]
#
# ...
#
# Parsed result: --("PPL105(a'2a2)(PDL05)--DPM", 'DPM', 0.12, '"PPL105(a\'2a2)(PDL05)--DPM" -> DPM [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2488449558400796 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)--DPM" -> DPM [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2488449558400796 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)--LHMB1", 'LHMB1', 0.1, '"PPL105(a\'2a2)(PDL05)--LHMB1" -> LHMB1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)--LHMB1" -> LHMB1 [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('LHMB1', 'LHMB1--APL', 1.0, 'LHMB1 -> "LHMB1--APL" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	LHMB1 -> "LHMB1--APL" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --('LHMB1--APL', 'APL', 0.1, '"LHMB1--APL" -> APL [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"LHMB1--APL" -> APL [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --('LHMB1', "LHMB1--PPL105(a'2a2)", 0.22, 'LHMB1 -> "LHMB1--PPL105(a\'2a2)" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4349878023756868 weight=3]')--, Line = 	LHMB1 -> "LHMB1--PPL105(a'2a2)" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4349878023756868 weight=3]
#
# Parsed result: --('DPM', "DPM--PPL105(a'2a2)(PDL05)", 0.1, 'DPM -> "DPM--PPL105(a\'2a2)(PDL05)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	DPM -> "DPM--PPL105(a'2a2)(PDL05)" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed Node found: "DPM--PPL105(a'2a2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)(PDL05)--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "APL--LHMB1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON03(B'2mp)--LHMB1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)--APL" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "DPM--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON13(a'2)" [label="MBON13(a'2) cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: "MBON03(B'2mp)" [label="MBON03(B'2mp) cent= 0.3" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.3 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)(PDL05)" [label="PPL105(a'2a2)(PDL05) cent= 0.4" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.4 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: APL [label="APL cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: "LHMB1--PPL105(a'2a2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "DPM--APL" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)(PDL05)--DPM" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHMB1--PPL105(a'2a2)(PDL05)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: DPM [label="DPM cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: "LHMB1--APL" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "DPM--PPL105(a'2a2)(PDL05)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "LHMB1--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: LHMB1 [label="LHMB1 cent= 0.5" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.5 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)" [label="PPL105(a'2a2) cent= 0.4" color=brown2 fixedsize=true fontcolor=white fontsize=5 height=0.4 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)(PDL05)--LHMB1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)(PDL05)--APL" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "MBON03(B'2mp)--MBON13(a'2)" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)--LHMB1" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "APL--DPM" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed Node found: "PPL105(a'2a2)--DPM" [label="" color=cyan fixedsize=true fontcolor=orange fontsize=5.0 height=0.05 shape=circle style=filled]
# Parsed result: --("PPL105(a'2a2)", "PPL105(a'2a2)--APL", 0.7, '"PPL105(a\'2a2)" -> "PPL105(a\'2a2)--APL" [label="Zscore = 0.7" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4051086053589321 weight=3]')--, Line = 	"PPL105(a'2a2)" -> "PPL105(a'2a2)--APL" [label="Zscore = 0.7" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.4051086053589321 weight=3]
#
# Parsed result: --("PPL105(a'2a2)", "PPL105(a'2a2)--DPM", 0.91, '"PPL105(a\'2a2)" -> "PPL105(a\'2a2)--DPM" [label="Zscore = 0.91" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.8100346807028522 weight=3]')--, Line = 	"PPL105(a'2a2)" -> "PPL105(a'2a2)--DPM" [label="Zscore = 0.91" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.8100346807028522 weight=3]
#
# Parsed result: --("MBON03(B'2mp)", "MBON03(B'2mp)--LHMB1", 0.26, '"MBON03(B\'2mp)" -> "MBON03(B\'2mp)--LHMB1" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5203264965252579 weight=3]')--, Line = 	"MBON03(B'2mp)" -> "MBON03(B'2mp)--LHMB1" [label="Zscore = 0.26" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.5203264965252579 weight=3]
#
# Parsed result: --("PPL105(a'2a2)", "PPL105(a'2a2)--LHMB1", 0.1, '"PPL105(a\'2a2)" -> "PPL105(a\'2a2)--LHMB1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"PPL105(a'2a2)" -> "PPL105(a'2a2)--LHMB1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("PPL105(a'2a2)", "PPL105(a'2a2)--MBON13(a'2)", 1.0, '"PPL105(a\'2a2)" -> "PPL105(a\'2a2)--MBON13(a\'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"PPL105(a'2a2)" -> "PPL105(a'2a2)--MBON13(a'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("PPL105(a'2a2)--MBON13(a'2)", "MBON13(a'2)", 1.0, '"PPL105(a\'2a2)--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"PPL105(a'2a2)--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("MBON03(B'2mp)", "MBON03(B'2mp)--MBON13(a'2)", 0.53, '"MBON03(B\'2mp)" -> "MBON03(B\'2mp)--MBON13(a\'2)" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.054452541681994 weight=3]')--, Line = 	"MBON03(B'2mp)" -> "MBON03(B'2mp)--MBON13(a'2)" [label="Zscore = 0.53" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.054452541681994 weight=3]
#
# Parsed result: --("MBON03(B'2mp)--MBON13(a'2)", "MBON13(a'2)", 0.36, '"MBON03(B\'2mp)--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7250388331548223 weight=3]')--, Line = 	"MBON03(B'2mp)--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7250388331548223 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)--APL", 0.79, '"PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)--APL" [label="Zscore = 0.79" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.583497403962864 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)--APL" [label="Zscore = 0.79" arrowsize=0.4 color=cyan3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.583497403962864 weight=3]
#
# Parsed result: --("DPM--PPL105(a'2a2)", "PPL105(a'2a2)", 1.0, '"DPM--PPL105(a\'2a2)" -> "PPL105(a\'2a2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"DPM--PPL105(a'2a2)" -> "PPL105(a'2a2)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("DPM--MBON13(a'2)", "MBON13(a'2)", 0.56, '"DPM--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 0.56" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.1257409141633068 weight=3]')--, Line = 	"DPM--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 0.56" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.1257409141633068 weight=3]
#
# Parsed result: --("LHMB1--PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)", 0.22, '"LHMB1--PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4306815132135282 weight=3]')--, Line = 	"LHMB1--PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4306815132135282 weight=3]
#
# Parsed result: --("LHMB1--MBON13(a'2)", "MBON13(a'2)", 0.48, '"LHMB1--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9592153740039366 weight=3]')--, Line = 	"LHMB1--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9592153740039366 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)--DPM", 1.0, '"PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)--DPM" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)--DPM" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)--LHMB1", 0.1, '"PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)--LHMB1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)--LHMB1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Parsed result: --("LHMB1--PPL105(a'2a2)", "PPL105(a'2a2)", 0.34, '"LHMB1--PPL105(a\'2a2)" -> "PPL105(a\'2a2)" [label="Zscore = 0.34" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6739416657989425 weight=3]')--, Line = 	"LHMB1--PPL105(a'2a2)" -> "PPL105(a'2a2)" [label="Zscore = 0.34" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6739416657989425 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)--MBON13(a'2)", 0.84, '"PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)--MBON13(a\'2)" [label="Zscore = 0.84" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.675127975091034 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)--MBON13(a'2)" [label="Zscore = 0.84" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.675127975091034 weight=3]
#
# Parsed result: --("PPL105(a'2a2)(PDL05)--MBON13(a'2)", "MBON13(a'2)", 0.48, '"PPL105(a\'2a2)(PDL05)--MBON13(a\'2)" -> "MBON13(a\'2)" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9644192971339169 weight=3]')--, Line = 	"PPL105(a'2a2)(PDL05)--MBON13(a'2)" -> "MBON13(a'2)" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9644192971339169 weight=3]
#
# Parsed result: --("DPM--PPL105(a'2a2)(PDL05)", "PPL105(a'2a2)(PDL05)", 1.0, '"DPM--PPL105(a\'2a2)(PDL05)" -> "PPL105(a\'2a2)(PDL05)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]')--, Line = 	"DPM--PPL105(a'2a2)(PDL05)" -> "PPL105(a'2a2)(PDL05)" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# ✅ Merged graph written to merged_data.gv with 118 unique edges.
# ✅ Unused itmes log written to merge_graphs/unused_log.gv with 5  items.

# %%
# specify the pattern to replace and the replacement text
#this should match any R or L suffix and remove all text within ()


#patterns = ['_[RL]_\d\d','\((.*?)\)']
#replacement_texts = ['', '']

# patterns = ['_[RL]','_\d','_C\d']
# replacement_texts = ['','','']

# # open the file in read mode
# with open('G_auto.gv', 'r') as file:
#     # read the file lines
#     lines = file.readlines()
#     oglines = lines
    
# # replace the patterns in each line
# for i in range(len(patterns)):
#     lines = [re.sub(patterns[i], replacement_texts[i], line) for line in lines]


# # open the file in write mode
# with open(noiFileName + '.gv', 'w') as postProcessfile:
#     # write the new lines to the file
#     postProcessfile.writelines(lines)
    

# # open the file containing the graph in read mode
# with open(noiFileName + '_all.gv', 'w') as postProcessfile:
#     # write the new lines to the file
#     postProcessfile.writelines(oglines)

# %% [markdown]
# # Other helper code

# %% [markdown]
# ## Python routine that scans the G_auto.gv file-identifies all edges with the same head and tail. This can pinpoint which ones might be collapsed due to concentrate=true.

# %%
import re
from collections import defaultdict

def find_edges_by_terminal_node(dot_path):
    edge_map = defaultdict(list)

    with open(dot_path, 'r') as f:
        for line in f:
            # Match basic edge syntax
            match = re.match(r'\s*"([^"]+)"\s*->\s*"([^"]+)"', line)
            if match:
                source, target = match.groups()
                # Extract final part if it's a compound edge
                simplified_source = source.split('--')[-1]
                simplified_target = target.split('--')[-1]
                key = (simplified_source, simplified_target)
                edge_map[key].append(line.strip())

    # Filter for multiple edges per neuron pair
    duplicates = {k: v for k, v in edge_map.items() if len(v) > 1}

    print(f"Found {len(duplicates)} terminal edge collisions:\n")
    for (src, tgt), lines in duplicates.items():
        print(f'Edges ending at "{tgt}" from "{src}": {len(lines)}')
        for l in lines:
            print(f'  {l}')
        print()

# Run it
find_edges_by_terminal_node('MBON13__35pre_001_002.gv')
# Out:
# Found 11 terminal edge collisions:
#
# Edges ending at "MBON13(a'2)_R_1" from "MBON13(a'2)_R_1": 24
#   "KCa'b'-m_R_50--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "LHMB1_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9592153740039366 weight=3]
#   "CRE055_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "CRE055_R_7--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_10--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_71--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-ap2_R_123--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_80--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "CRE057_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "PPL105(a'2a2)_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#   "KCa'b'-m_R_3--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "DPM_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.56" arrowsize=0.4 color=limegreen fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=1.1257409141633068 weight=3]
#   "MBON03(B'2mp)_L_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.36" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.7250388331548223 weight=3]
#   "CRE055_R_8--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "PPL105(a'2a2)(PDL05)_L_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.48" arrowsize=0.4 color=chartreuse fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.9644192971339169 weight=3]
#   "KCa'b'-m_R_85--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_39--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_81--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_14--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_82--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "CRE055_R_4--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_109--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-ap2_R_58--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_1--MBON13(a'2)_R_1" -> "MBON13(a'2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "PPL105(a'2a2)(PDL05)_L_1" from "PPL105(a'2a2)(PDL05)_L_1": 4
#   "KCa'b'-m_R_1--PPL105(a'2a2)(PDL05)_L_1" -> "PPL105(a'2a2)(PDL05)_L_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_82--PPL105(a'2a2)(PDL05)_L_1" -> "PPL105(a'2a2)(PDL05)_L_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "LHMB1_R_1--PPL105(a'2a2)(PDL05)_L_1" -> "PPL105(a'2a2)(PDL05)_L_1" [label="Zscore = 0.22" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.4306815132135282 weight=3]
#   "DPM_R_1--PPL105(a'2a2)(PDL05)_L_1" -> "PPL105(a'2a2)(PDL05)_L_1" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#
# Edges ending at "KCa'b'-m_R_85" from "KCa'b'-m_R_85": 2
#   "KCa'b'-m_R_50--KCa'b'-m_R_85" -> "KCa'b'-m_R_85" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_82--KCa'b'-m_R_85" -> "KCa'b'-m_R_85" [label="Zscore = 0.14" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2828069501775945 weight=3]
#
# Edges ending at "KCa'b'-m_R_71" from "KCa'b'-m_R_71": 3
#   "KCa'b'-m_R_81--KCa'b'-m_R_71" -> "KCa'b'-m_R_71" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_10--KCa'b'-m_R_71" -> "KCa'b'-m_R_71" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_1--KCa'b'-m_R_71" -> "KCa'b'-m_R_71" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "KCa'b'-m_R_82" from "KCa'b'-m_R_82": 2
#   "KCa'b'-ap2_R_123--KCa'b'-m_R_82" -> "KCa'b'-m_R_82" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_85--KCa'b'-m_R_82" -> "KCa'b'-m_R_82" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "PPL105(a'2a2)_R_1" from "PPL105(a'2a2)_R_1": 3
#   "KCa'b'-m_R_39--PPL105(a'2a2)_R_1" -> "PPL105(a'2a2)_R_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "DPM_R_1--PPL105(a'2a2)_R_1" -> "PPL105(a'2a2)_R_1" [label="Zscore = 1.0" arrowsize=0.4 color=blue fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=2.0 weight=3]
#   "LHMB1_R_1--PPL105(a'2a2)_R_1" -> "PPL105(a'2a2)_R_1" [label="Zscore = 0.34" arrowsize=0.4 color=gold fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.6739416657989425 weight=3]
#
# Edges ending at "KCa'b'-m_R_50" from "KCa'b'-m_R_50": 3
#   "KCa'b'-m_R_81--KCa'b'-m_R_50" -> "KCa'b'-m_R_50" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_10--KCa'b'-m_R_50" -> "KCa'b'-m_R_50" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_14--KCa'b'-m_R_50" -> "KCa'b'-m_R_50" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "KCa'b'-m_R_80" from "KCa'b'-m_R_80": 4
#   "KCa'b'-m_R_39--KCa'b'-m_R_80" -> "KCa'b'-m_R_80" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-ap2_R_58--KCa'b'-m_R_80" -> "KCa'b'-m_R_80" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_81--KCa'b'-m_R_80" -> "KCa'b'-m_R_80" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-ap2_R_123--KCa'b'-m_R_80" -> "KCa'b'-m_R_80" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "KCa'b'-ap2_R_58" from "KCa'b'-ap2_R_58": 3
#   "KCa'b'-ap2_R_123--KCa'b'-ap2_R_58" -> "KCa'b'-ap2_R_58" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_50--KCa'b'-ap2_R_58" -> "KCa'b'-ap2_R_58" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_39--KCa'b'-ap2_R_58" -> "KCa'b'-ap2_R_58" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "MBON03(B'2mp)_L_1" from "MBON03(B'2mp)_L_1": 9
#   "KCa'b'-ap2_R_58--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.24" arrowsize=0.4 color=orangered2 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.47324001226116286 weight=3]
#   "KCa'b'-m_R_109--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_3--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.19" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.38070910391335433 weight=3]
#   "KCa'b'-m_R_39--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_81--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.18" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.3575763768264024 weight=3]
#   "KCa'b'-m_R_85--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.24191274139164198 weight=3]
#   "KCa'b'-m_R_50--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.12" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.24191274139164198 weight=3]
#   "KCa'b'-ap2_R_123--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.14" arrowsize=0.4 color=orangered3 fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.288178195565546 weight=3]
#   "KCa'b'-m_R_82--MBON03(B'2mp)_L_1" -> "MBON03(B'2mp)_L_1" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#
# Edges ending at "KCa'b'-m_R_14" from "KCa'b'-m_R_14": 2
#   "KCa'b'-m_R_81--KCa'b'-m_R_14" -> "KCa'b'-m_R_14" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]
#   "KCa'b'-m_R_50--KCa'b'-m_R_14" -> "KCa'b'-m_R_14" [label="Zscore = 0.1" arrowsize=0.4 color=red fontcolor="#40e0d0" fontname=Ariel fontsize=5.0 labelfloat=false penwidth=0.2 weight=3]

# %% [markdown]
# ### Confirm digraph setup if needed

# %%
nodes = clean_graphviz_node_names(g.source)
edges = get_graphviz_edges(g.source)

unique_nodes = list(set(nodes))
print(f"🧠 Unique Nodes Actually Rendered: {len(unique_nodes)}")

# Force full output
import pprint
print("\n🧠 Full Node List:")
pprint.pprint(nodes, width=160)

print("\n🔗 Full Edge List:")
pprint.pprint(edges, width=160)
# Out:
# 🧠 Total Nodes Rendered: 0
# [] ...
#
# 🔗 Total Edges Rendered: 0
# 🧠 Unique Nodes Actually Rendered: 0
#
# 🧠 Full Node List:
# []
#
# 🔗 Full Edge List:
# []

# %%
dot_node_names = set(valid_nodes)  # based on your rendering logic
g_nodes = set(G.nodes())

extra_rendered_nodes = dot_node_names - g_nodes
print("🕵️ Nodes rendered but not present in graph:", extra_rendered_nodes)

# %%
print(f"✅ Synaptic nodes rendered: {len(synaptic_node_log)}")
display(JSON(synaptic_node_log, expanded=False))

print(f"⚠️ Non-synaptic nodes: {len(non_synaptic_node_log)}")
display(JSON(non_synaptic_node_log, expanded=False))

# expected_nodes = set(valid_nodes)
# unexpected = set(unique_nodes) - expected_nodes

# print(f"⚠️ Unexpected node names: {len(unexpected)}")
# from pprint import pprint
# pprint(list(unexpected))
# Out:
# ✅ Synaptic nodes rendered: 56
# ⚠️ Non-synaptic nodes: 0

# %%
import re

def clean_graphviz_node_names(dot_str):
    # Match everything in double quotes
    all_strings = re.findall(r'"([^"]+)"', dot_str)

    # Remove strings clearly used as edge labels
    label_noise = re.compile(r"Zscore = \d+(\.\d+)?")
    filtered_nodes = [s for s in all_strings if not label_noise.match(s)]

    # Keep only nodes that appear either in edge definitions or node blocks
    edge_pattern = re.compile(r'"([^"]+)"\s*->\s*"([^"]+)"')
    node_names_in_edges = set(sum(edge_pattern.findall(dot_str), ()))

    # Node candidates that look like IDs and appear in edge mappings
    node_names = [n for n in filtered_nodes if n in node_names_in_edges]

    print(f"🧠 Total Nodes Rendered: {len(node_names)}")
    print(node_names[:50], '...')

    return node_names

def get_graphviz_edges(dot_str):
    edge_pattern = re.compile(r'"([^"]+)"\s*->\s*"([^"]+)"')
    edges = edge_pattern.findall(dot_str)

    print(f"\n🔗 Total Edges Rendered: {len(edges)}")
    for src, dst in edges[:10]:
        print(f"{src} → {dst}")
    
    return edges

# %%
# # STEP 1: Render and save original graph
# g.attr(size='50,50')
# g.verbose = True
# try:
#     g.save('G_auto.gv')
#     g.render('G_auto', format='svg', view=False)
# except Exception as e:
#     self.raise_error(e, 'There was an error during diagram generation. Please execute "conda install -c anaconda graphviz" in your terminal in your conda environment, or try to install GraphViz globally from https://graphviz.org/download.')

# # STEP 2: Load .gv file as text
# with open("G_auto.gv", "r") as f:
#     gv_text = f.read()

# # STEP 3: Find declared and connected nodes
# declared_nodes = set(
#     match for match in re.findall(r'(\S+)\s*\[label=', gv_text)
#     if '--' not in match 
#     )


# edge_nodes = set()
# for src, dst in re.findall(r'(\S+)\s*->\s*(\S+)', gv_text):
#     edge_nodes.add(src.strip('"'))
#     edge_nodes.add(dst.strip('"'))

# # STEP 4: Find orphaned nodes
# orphans = declared_nodes - edge_nodes

# # STEP 5: Log orphaned nodes
# with open("G_orphan_log.txt", "w") as log_file:
#     for o in sorted(orphans):
#         log_file.write(f"Orphaned node removed: {o}\n")

# # STEP 6: Strip orphaned node definitions from source
# cleaned_lines = []
# for line in gv_text.splitlines():
#     if not any(line.strip().startswith(o + ' ') for o in orphans):
#         cleaned_lines.append(line)

# cleaned_gv = '\n'.join(cleaned_lines)

# # STEP 7: Render cleaned graph
# G_clean = Source(cleaned_gv)
# G_clean.render('G_cleaned', format='svg', view=False)

# # STEP 8: Filename sanitization
# nFilterStr = nFilter.replace('$','')
# for char in ['/r', ']', '[', '.', '*', '(', ')']:
#     nFilterStr = nFilterStr.replace(char, '')

# noiFileName = f"{noi}_{nFilterStr}_{nSys}{prePost}_001"
# shutil.copy('G_cleaned.svg', f"{noiFileName}.svg")

# %%
gv_text = g.source

# Step 1: Extract all nodes that appear in edge definitions
edges = re.findall(r'(\S+)\s*->\s*(\S+)', gv_text)
edge_nodes = set()
for src, dst in edges:
    edge_nodes.add(src.strip('"'))
    edge_nodes.add(dst.strip('"'))

# Step 2: Extract all declared nodes with label assignments
declared_nodes = set(re.findall(r'(\S+)\s* \[label=', gv_text))
declared_nodes = set(n.strip('"') for n in declared_nodes)

# Step 3: Find nodes declared but not used in any edge
orphan_nodes = declared_nodes - edge_nodes

# Step 4: Display results
print(f"🧠 Declared nodes: {len(declared_nodes)}")
print(f"🔗 Connected nodes: {len(edge_nodes)}")
print(f"🚫 Orphaned nodes: {len(orphan_nodes)}")
print("Orphans:")
for n in sorted(orphan_nodes):
    print("  -", n)

# %%
# Extract all nodes from each leg tuple (excluding the synapse type and weight)
missing_nodes = set()
for leg in unique_legs:
    _, node1, node2, _ = leg
    for node in [node1, node2]:
        print(node)
        if node not in valid_nodes:
            missing_nodes.add(node)

# Print out the missing nodes
for node in sorted(missing_nodes):
    print(f"Missing node: {node}")

# %%
# # Setup

# pw_default = 0.1
# pc_default = 'gray'
# minNormZscore = 0.2
# zScoreMultiplyer = 2

# skipped_edges_log = {}
# nodeDegreeDict = {}
# nodeNameZscoreDict = {}
# zScoreMultiplyer = 2
# penSettings = []
# valid_nodes = set()
# unique_nodes = set()
# skipped_edges_log = {}

# # #macro for name to id conversion
# # uname_to_id = {G.nodes[n]['uname']: n for n in G.nodes()}

# for head, tail, data in G.edges(data=True):
    
    
#     #print('pre= ' + str(head) + 'post= ' + str(tail))
#     pre_name = G.nodes(data=True)[head]['uname']
#     post_name = G.nodes(data=True)[tail]['uname']
#     valid_nodes.update([pre_name])
#     valid_nodes.update([post_name])


#     #check that the head and tail are in or z score dicts
#     #Each head and tail representa either syn->neuron or neuron->syn: NOT neur->neur
#     if head in preSynNumberDict.keys():

#         Zscore  = preSynNumberDict[head][2]
#         penSettings =  calcColor(Zscore)
        
#         add_graph_edge(g,
#             head=pre_name,
#             tail=post_name,
#             zscore = Zscore,
#             calcColorFn=calcColor)
        
        
#     elif tail in postSynNumberDict.keys():
#         Zscore = postSynNumberDict[tail][2]
#         penSettings = calcColor(Zscore)
    
#         #Get desired edge color and width
#         pw_pre = penSettings[0] * zScoreMultiplyer #pen width
#         pc_pre = penSettings[1]                    #pen color
        
#         add_graph_edge(g,
#                 head=pre_name,
#                 tail=post_name,
#                 zscore = Zscore,
#                 calcColorFn=calcColor)
#     else:
#         skipped_edges_log[f"{head}->{tail}"] = f"{pre_name} and {post_name} not found"         
                       
        
# print(f"⚠️ Skipped {len(skipped_edges_log)} synapse edges due to low Z-scores")
# from IPython.display import JSON, display
# display(JSON(skipped_edges_log, expanded=False))
# print(f"number of G nodes: {len(G.nodes())}")
# print(f"number of valid_nodes nodes: {len(valid_nodes)}")

# %%
my_client.tryComms??
# Out:
# Signature: my_client.tryComms(a)
# Source:
#     def tryComms(self, a):
#         """Communication function to communicate with a JupyterLab frontend if one exists.
#
#         # Arguments
#             a (obj): Arbitrarily formatted data to be sent via communication.
#         """
#         try:
#             for i in fbl.widget_manager.widgets:
#                 if fbl.widget_manager.widgets[i].widget_id not in fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets']:
#                     fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets'].append(fbl.widget_manager.widgets[i].widget_id)
#         except:
#             pass
#         try:
#             self.FBLcomm.send(data=a)
#         except:
#             pass
# File:      ~/miniconda/envs/ffbo/lib/python3.9/site-packages/flybrainlab/Client.py
# Type:      method

# %%
fbl.widget_manager??
# Out:
# Type:        WidgetManager
# String form: <flybrainlab.widget.WidgetManager object at 0x7fd8939e8ac0>
# File:        ~/miniconda/envs/ffbo/lib/python3.9/site-packages/flybrainlab/widget.py
# Source:
# class WidgetManager(object):
#     """Widget Manager class that keeps track of all widgets associated with the current FBLClient session.
#
#     # Attributes:
#         widgets (dict): a dictionary of instances of Widget.
#         _comms (dict): all comm objects opend for this client.
#         last_active (Widget): last active widget based on comm
#     """
#
#     def __init__(self):
#         self._comms = OrderedDict()
#         self.widgets = OrderedDict()
#         self.callback_manager = CallbackManager()
#         self.last_active = None
#
#     def add_widget(self, widget_id, client_id, widget_type, comm_target):
#         """Add a widget to manager.
#
#         # Returns:
#
#         """
#         comm = self.find_comm(comm_target=comm_target) # Try to find a comm object
#         if not comm: # Create comm if does not exist
#             comm = Comm(target_name=comm_target)
#             self._comms[widget_id] = comm
#
#             @comm.on_msg
#             def handle_msg(msg):
#                 comm_id = msg["content"]["comm_id"]
#                 data = msg["content"]["data"]
#                 nonlocal self
#                 widget = self.find_widget_by_comm_id(comm_id)
#                 self.last_active = widget
#                 widget.msg_data = data
#                 widget.parse_data(data)
#                 if data == "dispose":
#                     widget.isDisposed = True
#                 self.callback_manager.run(comm_id, data)
#
#             @comm.on_close
#             def handle_close(msg):
#                 comm_id = msg["content"]["comm_id"]
#                 nonlocal self
#                 widget = self.find_widget_by_comm_id(comm_id)
#                 widget.commOpen = False
#
#         if widget_id not in self.widgets:
#             self.widgets[widget_id] = Widget(
#                 widget_type=widget_type,
#                 widget_id=widget_id,
#                 client_id = client_id,
#                 model=None,
#                 comm=comm,
#                 isDisposed=False,
#                 msg_data=None,
#             )
#         self.last_active = self.widgets[widget_id]
#
#         # make sure that comm is open
#         comm.open()
#
#     def find_comm(self, comm_id=None, comm_target=None):
#         """Find a comm object either by id or by target name
#         """
#         if comm_id:
#             comm = [c for c in self._comms.values() if c.comm_id == comm_id]
#         elif comm_target:
#             comm = [c for c in self._comms.values() if c.target_name == comm_target]
#         else:
#             comm = []
#         if len(comm) == 1:
#             return comm[0]
#         else:
#             return None
#
#     def find_widget_by_comm_id(self, comm_id):
#         w = [w for w in self.widgets.values() if w.comm.comm_id == comm_id]
#         if len(w) == 1:
#             return w[0]
#         else:
#             return None
#
#     def send_data(self, widget_id, data):
#         if widget_id in self.widgets:
#             self.widgets[widget_id].send_data(data)
#             self.last_active = self.widgets[widget_id]
