# %%
import os
import traceback
import pdb #debug
import time
import shutil
import math
import re
import csv
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

import networkx as nx
from graphviz import Digraph
from graphviz import Source

from IPython.display import display, JSON
from scipy import stats

# %matplotlib inline
my_client = fbl.get_client()

# %% [markdown]
# # R23E10

# %%
#turn on breakpoints?
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
# !git init
# !git remote add origin https://github.com/sgarnell/archive
# Out:
# Reinitialized existing Git repository in /home/ffbo/ffbo/.git/
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/sgarnell/archive.git (fetch)
# origin	https://github.com/sgarnell/archive.git (push)

# %%
# Stage the notebook file
# !git add 'pathfinder_MBON03_v2.ipynb'

# Commit the changes
# !git commit -m "Auto commit from Jupyter for {notebook_name}"

# Push to GitHub
# !git push origin fbl2-main  # Replace 'main' with 'master' if needed

# %% [markdown]
# # First Graph
# ## All NOIs except those that innervate between the CRE and FB-ExR
# ### Note that because FB5AB innervates between the SIP and FB, we include it in this section

# %%
noi = 'MBON03'
nFilterStr = 'EX_CRE_MB_SMP_LH'
prePost = 'fullCircuit_g1_v2'
noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')

# %%
data = my_client.executeNLPquery('clear')
# Out:
# [FBL NLP 2025-08-06 20:41:34,921] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON15")
# Out:
# [FBL NLP 2025-08-06 20:41:37,648] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON31")
# Out:
# [FBL NLP 2025-08-06 20:41:42,114] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON09")
# Out:
# [FBL NLP 2025-08-06 20:41:48,918] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON03")
# Out:
# [FBL NLP 2025-08-06 20:41:52,287] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON12")
# Out:
# [FBL NLP 2025-08-06 20:41:54,181] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add MBON26")
# Out:
# [FBL NLP 2025-08-06 20:41:56,202] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $MBON$ blue")
# Out:
# [FBL NLP 2025-08-06 20:41:58,949] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE066$")
# Out:
# [FBL NLP 2025-08-06 20:42:04,021] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE025$")
# Out:
# [FBL NLP 2025-08-06 20:42:10,424] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE042$")
# Out:
# [FBL NLP 2025-08-06 20:42:13,146] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE054$")
# Out:
# [FBL NLP 2025-08-06 20:42:17,550] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE057$")
# Out:
# [FBL NLP 2025-08-06 20:42:20,211] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE107$")
# Out:
# [FBL NLP 2025-08-06 20:42:22,051] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE043$")
# Out:
# [FBL NLP 2025-08-06 20:42:24,915] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $CRE$ orange")
# Out:
# [FBL NLP 2025-08-06 20:42:30,414] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $DPM$")
# Out:
# [FBL NLP 2025-08-06 20:42:39,118] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $APL$")
# Out:
# [FBL NLP 2025-08-06 20:42:48,625] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color /r(.*)(.*)APL|DPM(.*)/r cyan")
# Out:
# [FBL NLP 2025-08-06 20:42:55,058] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $PPL103$")
# Out:
# [FBL NLP 2025-08-06 20:42:57,895] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /r(.*)PPL106(.*)_R(.*)/r")
# Out:
# [FBL NLP 2025-08-06 20:43:02,812] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $PPL$ red")
# Out:
# [FBL NLP 2025-08-06 20:43:06,352] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add /r(.*)PAM06_a(.*)_R(.*)/r")
# Out:
# [FBL NLP 2025-08-06 20:43:08,356] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $PAM$ lime")
# Out:
# [FBL NLP 2025-08-06 20:43:13,643] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SMP146$")
# Out:
# [FBL NLP 2025-08-06 20:43:15,581] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SMP197$")
# Out:
# [FBL NLP 2025-08-06 20:43:19,855] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SMP177$")
# Out:
# [FBL NLP 2025-08-06 20:43:26,339] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SIP087$")
# Out:
# [FBL NLP 2025-08-06 20:43:30,214] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SIP029$")
# Out:
# [FBL NLP 2025-08-06 20:43:32,353] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color /r(.*)(.*)SIP|SMP(.*)/r magenta")
# Out:
# [FBL NLP 2025-08-06 20:43:35,935] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $LHCENT5$")
# Out:
# [FBL NLP 2025-08-06 20:43:49,588] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $LHPV5e1$")
# Out:
# [FBL NLP 2025-08-06 20:43:50,325] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5AB$")
# Out:
# [FBL NLP 2025-08-06 20:43:54,403] NLP successfully parsed query.

# %% [markdown]
# # Second Graph
# ## This Graphs has a clear separation to and from the CRE
# ### Note that the CRE here should be identical to the above because these neurons represent the nexus between graph 1 and 2

# %%
noi = 'MBON03'
nFilterStr = 'EX_PEN__CRE_MB_SMP_LH'
prePost = 'fullCircuit_g2_v2'
noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')

# %%
data = my_client.executeNLPquery('clear')
# Out:
# [FBL NLP 2025-09-04 19:44:48,668] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE066$")
# Out:
# [FBL NLP 2025-09-04 19:44:51,535] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE025$")
# Out:
# [FBL NLP 2025-09-04 19:44:55,736] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE042$")
# Out:
# [FBL NLP 2025-09-04 19:45:00,006] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE054$")
# Out:
# [FBL NLP 2025-09-04 19:45:03,806] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE057$")
# Out:
# [FBL NLP 2025-09-04 19:45:06,418] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE107$")
# Out:
# [FBL NLP 2025-09-04 19:45:08,673] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE043$")
# Out:
# [FBL NLP 2025-09-04 19:45:11,448] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $CRE$ orange")
# Out:
# [FBL NLP 2025-09-04 19:45:15,405] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $ExR5$")
# Out:
# [FBL NLP 2025-09-04 19:45:17,942] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $ExR7$")
# Out:
# [FBL NLP 2025-09-04 19:45:20,350] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $Ex$ blue")
# Out:
# [FBL NLP 2025-09-04 19:45:22,539] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB4F$")
# Out:
# [FBL NLP 2025-09-04 19:45:23,592] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB4Y$")
# Out:
# [FBL NLP 2025-09-04 19:45:27,405] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5K$")
# Out:
# [FBL NLP 2025-09-04 19:45:30,670] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5M$")
# Out:
# [FBL NLP 2025-09-04 19:45:35,040] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5N$")
# Out:
# [FBL NLP 2025-09-04 19:45:37,873] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5H$")
# Out:
# [FBL NLP 2025-09-04 19:45:40,703] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB5AB$")
# Out:
# [FBL NLP 2025-09-04 19:45:43,999] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $FB$ lime")
# Out:
# [FBL NLP 2025-09-04 19:45:46,417] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $PEN$")
# Out:
# [FBL NLP 2025-09-04 19:45:49,098] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("color $PEN$ pink")
# Out:
# [FBL NLP 2025-09-04 19:45:59,281] NLP successfully parsed query.

# %% [markdown]
# # Third Graph
# ## This Graphs includes vector based EB signals
# ### Note:

# %%
noi = 'MBON03'
nFilterStr = 'PEN_EPG_FB4_CRE_SMP_SIP'
prePost = 'fullCircuit_g3_v1'
noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')

# %%
data = my_client.executeNLPquery('clear')
# Out:
# [FBL NLP 2025-09-05 16:00:45,882] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $PEN$")
# Out:
# [FBL NLP 2025-09-05 16:00:51,113] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $EPG$")
# Out:
# [FBL NLP 2025-09-05 16:01:01,196] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $hDeltaA$")
# Out:
# [FBL NLP 2025-09-05 16:01:11,134] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $FB4Y$")
# Out:
# [FBL NLP 2025-09-05 16:01:15,737] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $CRE011$")
# Out:
# [FBL NLP 2025-09-05 16:01:20,153] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SMP177$")
# Out:
# [FBL NLP 2025-09-05 16:01:24,290] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery("add $SIP087$")
# Out:
# [FBL NLP 2025-09-05 16:01:27,416] NLP successfully parsed query.

# %% [markdown]
# # End of Selection

# %%
data = my_client.executeNLPquery(f"remove {neuronsToExclude}")
# Out:
# [FBL NLP 2025-09-07 01:27:41,310] NLP successfully parsed query.

# %% [markdown]
# # Ignore This section if the above NOIs have been used

# %%
# noi = 'MBON0[12]'
noi = 'EPG'
neuronsToExclude = '/r(.*)NPFL(.*)/r'
noi2 = f"/r(.*){noi}(.*)(.*)/r"
prePost = 'post'
nSys = 25
nFilter = '/r(.*)(.*)(.*)/r'
nplQuery = f"show {noi2} neurons"
print(nplQuery)
data = my_client.executeNLPquery(nplQuery)
nFilterStr = ''
noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')
# Out:
# show /r(.*)EPG(.*)(.*)/r neurons
# [FBL NLP 2025-09-07 01:32:09,569] NLP successfully parsed query.

# %%
data = my_client.executeNLPquery(f"add {prePost}synaptic {nFilter} neurons with at least {nSys} synapses")
# Out:
# [FBL NLP 2025-09-07 01:32:23,457] NLP successfully parsed query.

# %% [markdown]
# # Begin Synaptic data aggregation

# %%
# ⏱️ Timer start
start_time = time.time()

neurons = my_client.NLP_result.neurons
hashids = list(neurons.keys())
names = [neurons[k]['uname'] for k in hashids]

# 🧠 Synapse collection
preSynapses = []
postSynapses = []

for i, hashid in enumerate(hashids):
    res = my_client.getInfo(hashid)
    data = res["data"]

    if "connectivity" in data:
        presyn = data["connectivity"]["pre"]["details"]
        postsyn = data["connectivity"]["post"]["details"]

        for syn in presyn:
            preSynapses.append(("pre", syn["syn_uname"], names[i], syn["uname"],
                                syn["s_rid"], syn["number"], True))

        for syn in postsyn:
            postSynapses.append(("post", syn["syn_uname"], names[i], syn["uname"],
                                 syn["s_rid"], syn["number"], True))

# 🧩 NumPy structured arrays
dtype = [('type', 'U4'), ('syn_uname', 'U100'), ('neuron_name', 'U100'),
         ('uname', 'U100'), ('s_rid', 'U100'), ('number', 'f8'), ('valid', 'bool')]

pre_array = np.array(preSynapses, dtype=dtype)
post_array = np.array(postSynapses, dtype=dtype)

# 🔍 Filter out 'segment' entries efficiently
pre_array = pre_array[np.char.find(pre_array['uname'], 'segment') == -1]
post_array = post_array[np.char.find(post_array['uname'], 'segment') == -1]

connectivity = {"hashids": hashids, "names": names, "pre_array": pre_array, "post_array": post_array}

# 📊 Dictionary construction
postSynNumberDict = {}
preSynNumberDict = {}

def process_array(array, synNumberDict, synType):
    neuron_names = np.unique(array['neuron_name'])
    for neuron in neuron_names:
        mask = array['neuron_name'] == neuron
        syn_data = array[mask]
        syn_numbers = syn_data['number']

        if syn_numbers.size == 0:
            continue

        z_scores = stats.zscore(syn_numbers)

        if np.any(np.isnan(z_scores)):
            array['valid'][mask] = False
            print(f'\033[93m{neuron} Error: Nan Value Found in array\033[0m')
            continue

        zmax = np.max(z_scores)
        norm_scores = 1 - ((zmax - z_scores) / zmax)

        print(f'\033[92m{neuron}: {synType}SynZmax= {zmax}\033[0m')

        for uname, rid, z, norm in zip(syn_data['syn_uname'], syn_data['s_rid'], z_scores, norm_scores):
            synNumberDict[rid] = [uname, z, norm]

process_array(connectivity["post_array"], postSynNumberDict, "post")
process_array(connectivity["pre_array"], preSynNumberDict, "pre")

# 🕒 Timing metrics
numberOfNodes = len(names)
end_time = time.time()
elapsed_time = end_time - start_time

avSynCalc_time = elapsed_time / (len(pre_array) + len(post_array))
avNeuronCalc_time = elapsed_time / numberOfNodes

avSynCalc_time = 10

if elapsed_time > avSynCalc_time:
    gvLayoutEngine = 'neato'
    gGraphvizMode = 'sgd'
else:
    gvLayoutEngine = 'sfdp'
    gGraphvizMode = 'spring'

print ("No. of HashIDs= " + str( len(hashids)))
print ("No. of names= " + str( numberOfNodes ))
print ("No. of preSynapses= " + str( len(preSynapses)))
print ("No. of postSynapses= " + str( len(postSynapses)))
print(f"Elapsed time: {elapsed_time:.2f} seconds")
print(f"Avg. time per synapse: {avSynCalc_time:.4f} seconds")
print(f"Avg. time per neuron: {avNeuronCalc_time:.4f} seconds")
print(f"Graphviz  set to Engine: {gvLayoutEngine} and Mode:{gGraphvizMode} ")
# Out:
# FB4Z_L_5: postSynZmax= 4.16740042266577
# FB4Z_L_6: postSynZmax= 5.093081657236249
# FB4Z_L_8: postSynZmax= 5.339492348330388
# FB4Z_R_3: postSynZmax= 6.693640720205721
# FB4Z_R_4: postSynZmax= 4.943066874313246
# FB4Z_R_6: postSynZmax= 3.524239297176207
# FB4Z_R_7: postSynZmax= 4.151705968590068
# FB4Z_R_8: postSynZmax= 5.47951656123057
# FS1A(FQ9)_C6_L_2: postSynZmax= 6.511085528876772
# PFL2(PB12b)_L2_C6_1: postSynZmax= 8.553782784884115
# PFL2(PB12b)_L3_C7_1: postSynZmax= 8.055605650942132
# PFL2(PB12b)_L3_C7_2: postSynZmax= 7.870725695147419
# PFL2(PB12b)_L4_C8_1: postSynZmax= 6.9613308676738495
# PFL2(PB12b)_L5_C9_1: postSynZmax= 6.609792750022562
# PFL2(PB12b)_R2_C4_1: postSynZmax= 6.8945221838199355
# PFL2(PB12b)_R3_C3_1: postSynZmax= 7.408917232314845
# PFL2(PB12b)_R3_C3_2: postSynZmax= 8.113182552849059
# PFL2(PB12b)_R4_C2_1: postSynZmax= 7.65477553023545
# PFL2(PB12b)_R5_C1_1: postSynZmax= 7.9985766947607955
# PFL3(PB12c)_L1_C3_1: postSynZmax= 8.36320918615951
# PFL3(PB12c)_L1_C3_2: postSynZmax= 7.577292136054349
# PFL3(PB12c)_L1_C8_irreg_1: postSynZmax= 3.0
# PFL3(PB12c)_L2_C4_1: postSynZmax= 8.998559596642675
# PFL3(PB12c)_L2_C9_irreg_1: postSynZmax= 4.13802944301184
# PFL3(PB12c)_L3_C5_1: postSynZmax= 8.61567265415498
# PFL3(PB12c)_L3_C5_2: postSynZmax= 8.06287326761824
# PFL3(PB12c)_L4_C6_1: postSynZmax= 9.07614650831699
# PFL3(PB12c)_L5_C7_1: postSynZmax= 7.511313051808561
# PFL3(PB12c)_L5_C7_2: postSynZmax= 8.286995531811549
# PFL3(PB12c)_L6_C8_1: postSynZmax= 8.87382038317985
# PFL3(PB12c)_L7_C9_1: postSynZmax= 7.773797974350057
# PFL3(PB12c)_R1_C2_irreg_1: postSynZmax= 9.721724835406778
# PFL3(PB12c)_R1_C7_1 Error: Nan Value Found in array
# PFL3(PB12c)_R1_C7_2: postSynZmax= 5.273546187250807
# PFL3(PB12c)_R2_C1_irreg_1: postSynZmax= 9.031444955826984
# PFL3(PB12c)_R2_C6_1: postSynZmax= 3.8771794290699586
# PFL3(PB12c)_R3_C5_1: postSynZmax= 3.0
# PFL3(PB12c)_R3_C5_2 Error: Nan Value Found in array
# PFL3(PB12c)_R4_C4_1 Error: Nan Value Found in array
# PFL3(PB12c)_R5_C3_1: postSynZmax= 3.1224989991991996
# PFL3(PB12c)_R5_C3_2: postSynZmax= 4.86708584166788
# PFL3(PB12c)_R6_C2_1: postSynZmax= 5.0
# PFL3(PB12c)_R7_C1_1: postSynZmax= 5.058203075424825
# PFR_a(PB11a)_L1_C9_irreg_1: postSynZmax= 10.332828939342097
# PFR_a(PB11a)_L1_C9_irreg_2: postSynZmax= 10.698029220127754
# PFR_a(PB11a)_L2_C2_1: postSynZmax= 8.916710347942137
# PFR_a(PB11a)_L2_C2_2: postSynZmax= 9.316053689558581
# PFR_a(PB11a)_L3_C3_2: postSynZmax= 7.786652633630688
# PFR_a(PB11a)_L4_C4_1: postSynZmax= 7.938716544891484
# PFR_a(PB11a)_L6_C6_1: postSynZmax= 9.712909893753856
# PFR_a(PB11a)_R1_C1_irreg_1: postSynZmax= 9.88875116101589
# PFR_a(PB11a)_R1_C1_irreg_2: postSynZmax= 10.031862303904754
# PFR_a(PB11a)_R2_C8_3: postSynZmax= 8.834324662934494
# PFR_a(PB11a)_R4_C6_1: postSynZmax= 6.659030670349118
# PFR_a(PB11a)_R4_C6_2: postSynZmax= 7.060515920680123
# PFR_a(PB11a)_R5_C5_2: postSynZmax= 8.82302620036192
# PFR_a(PB11a)_R6_C3_1: postSynZmax= 9.349399383656793
# PFR_a(PB11a)_R6_C4_1: postSynZmax= 12.47039111786048
# PFR_b(PB11b)_L1_C2_1: postSynZmax= 12.51857649684683
# PFR_b(PB11b)_L3_C3_1: postSynZmax= 8.633580440781923
# PFR_b(PB11b)_L7_C8_1: postSynZmax= 12.905948505464806
# PFR_b(PB11b)_R1_C1_irreg_1: postSynZmax= 11.615581250116747
# PFR_b(PB11b)_R1_C8_1: postSynZmax= 6.490583708474763
# PFR_b(PB11b)_R3_C6_1: postSynZmax= 7.888026738324112
# PFR_b(PB11b)_R4_C5_1: postSynZmax= 5.81158099384866
# PFR_b(PB11b)_R6_C3_1: postSynZmax= 6.444553637718842
# hDeltaA_01_C1_1: postSynZmax= 5.196055173842032
# hDeltaA_02_C2_1: postSynZmax= 5.520651889029635
# hDeltaA_03_C3_1: postSynZmax= 5.238460287586273
# hDeltaA_04_C4_1: postSynZmax= 6.599828703866097
# hDeltaA_05_C5_1: postSynZmax= 5.747331660255449
# hDeltaA_07_C6_1: postSynZmax= 6.585563973606187
# hDeltaA_08_C7_1: postSynZmax= 8.717705950938361
# hDeltaA_10_C8_1: postSynZmax= 5.421073545664311
# hDeltaA_11_C9_1: postSynZmax= 6.65970317210763
# hDeltaA_12_C10_1: postSynZmax= 6.250080976883918
# hDeltaA_13_C11_1: postSynZmax= 6.6097018191814625
# hDeltaA_14_C12_1: postSynZmax= 4.6986268576129495
# hDeltaI_01_C1_1: postSynZmax= 6.589529158518046
# hDeltaI_02_C2_1: postSynZmax= 8.0681778644301
# hDeltaI_06_C5_1: postSynZmax= 6.4293747185323165
# hDeltaI_07_C6_1: postSynZmax= 6.927056369617037
# hDeltaI_08_C7_1: postSynZmax= 8.164597740873456
# hDeltaI_09_C8_1: postSynZmax= 6.751144399573208
# FB4Z_L_5: preSynZmax= 5.188375080176109
# FB4Z_L_6: preSynZmax= 5.449889877559076
# FB4Z_L_8: preSynZmax= 5.544908924338565
# FB4Z_R_3: preSynZmax= 7.3585422080496965
# FB4Z_R_4: preSynZmax= 5.411987636086782
# FB4Z_R_6: preSynZmax= 5.561944232407188
# FB4Z_R_7: preSynZmax= 6.091352326391119
# FB4Z_R_8: preSynZmax= 5.070130473540333
# FS1A(FQ9)_C6_L_2: preSynZmax= 10.941918470533626
# PFL2(PB12b)_L2_C6_1: preSynZmax= 6.558568864802478
# PFL2(PB12b)_L3_C7_1: preSynZmax= 7.529678393519065
# PFL2(PB12b)_L3_C7_2: preSynZmax= 7.390972448559677
# PFL2(PB12b)_L4_C8_1: preSynZmax= 7.244949707065858
# PFL2(PB12b)_L5_C9_1: preSynZmax= 6.71064167569595
# PFL2(PB12b)_R2_C4_1: preSynZmax= 6.637435564059699
# PFL2(PB12b)_R3_C3_1: preSynZmax= 6.260774473388791
# PFL2(PB12b)_R3_C3_2: preSynZmax= 5.618593821912149
# PFL2(PB12b)_R4_C2_1: preSynZmax= 6.201203044098422
# PFL2(PB12b)_R5_C1_1: preSynZmax= 7.5481169810236155
# PFL3(PB12c)_L1_C3_1: preSynZmax= 7.1604372327347585
# PFL3(PB12c)_L1_C3_2: preSynZmax= 7.324634055365523
# PFL3(PB12c)_L1_C8_irreg_1: preSynZmax= 8.108244362706358
# PFL3(PB12c)_L2_C4_1: preSynZmax= 8.32202730446187
# PFL3(PB12c)_L2_C9_irreg_1: preSynZmax= 7.4783328972379275
# PFL3(PB12c)_L3_C5_1: preSynZmax= 7.408598071914553
# PFL3(PB12c)_L3_C5_2: preSynZmax= 7.093429421496404
# PFL3(PB12c)_L4_C6_1: preSynZmax= 6.494758994248857
# PFL3(PB12c)_L5_C7_1: preSynZmax= 7.0958208872234545
# PFL3(PB12c)_L5_C7_2: preSynZmax= 8.244055386372947
# PFL3(PB12c)_L6_C8_1: preSynZmax= 8.107379300261114
# PFL3(PB12c)_L7_C9_1: preSynZmax= 9.058376863526448
# PFL3(PB12c)_R1_C2_irreg_1: preSynZmax= 7.517041677628867
# PFL3(PB12c)_R1_C7_1: preSynZmax= 7.586339602116602
# PFL3(PB12c)_R1_C7_2: preSynZmax= 8.156651944782316
# PFL3(PB12c)_R2_C1_irreg_1: preSynZmax= 8.978401193740698
# PFL3(PB12c)_R2_C6_1: preSynZmax= 7.538739855453884
# PFL3(PB12c)_R3_C5_1: preSynZmax= 8.812492345600496
# PFL3(PB12c)_R3_C5_2: preSynZmax= 6.135519852501329
# PFL3(PB12c)_R4_C4_1: preSynZmax= 6.696296001819106
# PFL3(PB12c)_R5_C3_1: preSynZmax= 7.714976721508775
# PFL3(PB12c)_R5_C3_2: preSynZmax= 8.407433846040185
# PFL3(PB12c)_R6_C2_1: preSynZmax= 6.697488662009887
# PFL3(PB12c)_R7_C1_1: preSynZmax= 9.663492538576206
# PFR_a(PB11a)_L1_C9_irreg_1: preSynZmax= 11.92893828953227
# PFR_a(PB11a)_L1_C9_irreg_2: preSynZmax= 10.516307614088248
# PFR_a(PB11a)_L2_C2_1: preSynZmax= 8.204054751413159
# PFR_a(PB11a)_L2_C2_2: preSynZmax= 10.16567759801148
# PFR_a(PB11a)_L3_C3_2: preSynZmax= 7.199159499834198
# PFR_a(PB11a)_L4_C4_1: preSynZmax= 10.334387898017672
# PFR_a(PB11a)_L6_C6_1: preSynZmax= 10.38529508568761
# PFR_a(PB11a)_R1_C1_irreg_1: preSynZmax= 9.920327266653363
# PFR_a(PB11a)_R1_C1_irreg_2: preSynZmax= 11.354867029311233
# PFR_a(PB11a)_R2_C8_3: preSynZmax= 7.67718218374556
# PFR_a(PB11a)_R4_C6_1: preSynZmax= 9.8846305773344
# PFR_a(PB11a)_R4_C6_2: preSynZmax= 9.677158670672883
# PFR_a(PB11a)_R5_C5_2: preSynZmax= 10.562719971214205
# PFR_a(PB11a)_R6_C3_1: preSynZmax= 7.500207289878026
# PFR_a(PB11a)_R6_C4_1: preSynZmax= 9.721726066232785
# PFR_b(PB11b)_L1_C2_1: preSynZmax= 9.463287962571638
# PFR_b(PB11b)_L3_C3_1: preSynZmax= 9.717035966846597
# PFR_b(PB11b)_L7_C8_1: preSynZmax= 10.046304383717441
# PFR_b(PB11b)_R1_C1_irreg_1: preSynZmax= 13.176833890864568
# PFR_b(PB11b)_R1_C8_1: preSynZmax= 8.988537410075862
# PFR_b(PB11b)_R3_C6_1: preSynZmax= 14.125006118526994
# PFR_b(PB11b)_R4_C5_1: preSynZmax= 11.846776579426374
# PFR_b(PB11b)_R6_C3_1: preSynZmax= 9.591516560314654
# hDeltaA_01_C1_1: preSynZmax= 5.140019478873727
# hDeltaA_02_C2_1: preSynZmax= 4.714745005253068
# hDeltaA_03_C3_1: preSynZmax= 4.7012582447973905
# hDeltaA_04_C4_1: preSynZmax= 4.844680715683448
# hDeltaA_05_C5_1: preSynZmax= 5.869948476895672
# hDeltaA_07_C6_1: preSynZmax= 5.512759688047547
# hDeltaA_08_C7_1: preSynZmax= 6.529976319107961
# hDeltaA_10_C8_1: preSynZmax= 4.91455364785705
# hDeltaA_11_C9_1: preSynZmax= 6.81427846389392
# hDeltaA_12_C10_1: preSynZmax= 3.90763837158353
# hDeltaA_13_C11_1: preSynZmax= 4.817841979211805
# hDeltaA_14_C12_1: preSynZmax= 6.42092213032851
# hDeltaI_01_C1_1: preSynZmax= 10.981102564418695
# hDeltaI_02_C2_1: preSynZmax= 10.399631836079168
# hDeltaI_06_C5_1: preSynZmax= 5.700865560950436
# hDeltaI_07_C6_1: preSynZmax= 9.213587248154255
# hDeltaI_08_C7_1: preSynZmax= 7.852189904349941
# hDeltaI_09_C8_1: preSynZmax= 7.18571802093055
# No. of HashIDs= 84
# No. of names= 84
# No. of preSynapses= 26225
# No. of postSynapses= 24962
# Elapsed time: 131.42 seconds
# Avg. time per synapse: 10.0000 seconds
# Avg. time per neuron: 1.5645 seconds
# Graphviz  set to Engine: neato and Mode:sgd

# %% [markdown]
# ### optional WRITE Neurons to file

# %%
#output to CSV if needed
with open('preOutput.csv','w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['type','syn_name','uname','s_rid','hashid','number'])
    writer.writerows(preSynapses)

# %%
with open('postOutput.csv','w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['type','syn_name','uname','s_rid','hashid','number'])
    writer.writerows(postSynapses)

# %% [markdown]
# ### continue from here

# %%
res = my_client.getConnectivity()
nodes = dict(res.graph.nodes(data=True))
edges = list(res.graph.edges(data=True))

#sample outputs 
#print(edges)
#print(edges[0][0])
#display(JSON(nodes))
#print(edges)

# %%
display(JSON(nodes, expanded = False))
display(JSON(edges, expanded = False))

# %%
# Step 1: Add nodes (and catch malformed ones)
G = nx.DiGraph()

for e_pre in nodes:
    try:
        uname_val = nodes[e_pre]['uname']
        G.add_node(e_pre, uname=uname_val)
    except KeyError as e:
        print(f"⚠️ Node {e_pre} skipped: missing 'uname'")
        continue

# Step 2: Add edges
for edge in edges:
    try:
        G.add_edge(edge[0], edge[1])
    except KeyError as e:
        print(f"⚠️ Edge {edge} skipped: {e.args[0]}")
        continue

# Step 3: Compute centrality
centralityDict = nx.betweenness_centrality(G, normalized=True)

# Step 4: Assign centrality only to valid graph nodes
for node in G.nodes():
    G.nodes[node]['centrality'] = centralityDict.get(node, 0.0)

# %%
#GraphViz
#Rndering the final output ot NeuGFX

#false = line , ortho is curved for example
gvSplines = "false"

graph_struct = {'verbose':'false',
                'splines': gvSplines,
                'pad': '0.5',
                'ranksep': '1.5',
                'concentrate': 'true',
                'newrank': 'true',
                'rankdir': 'LR'}


edgeFontSize = '4.0'
edgeFontColor = "#40e0d0"
edgeFontName = "Ariel"
gvSize = '50,50'
#gvLayout = 'dot'
#gvLayout = 'sfdp'

g = Digraph('G', 
            filename ='G_ex.gv',
            graph_attr = {  'size': gvSize,
                            'layout':gvLayoutEngine,
                            'fontcolor':edgeFontColor,
                            'fontsize':edgeFontSize,
                            'fontname':edgeFontName,
                            'overlap_scaling':'2',
                            'rotation':'0',
                            'mode':gGraphvizMode,
                            'beautify':'false',
                            'splines': 'false',
                            'arrowsize': '0.5',
                            'overlap': 'false',
                            'pad': '0.1',
                            'quadtree':'true',
                            'nodesep': '0.1',
                            'outputorder': 'edgesfirst',
                            'ranksep': '0.2',
                            'bgcolor': '#212529',
                            'colorscheme':'rdylgn8',
                            'concentrate': 'true',
                            'newrank': 'true',
                            'rankdir': 'LR'})

# %%
def calcColor(normalizedScore):
    
    retlist = []
    pw_default = 0.1
    pc_default = 'gray'
    pw = pw_default
    pc = pc_default

    if normalizedScore is None:
        pw = pw_default
        pc=  pc_defult
    elif normalizedScore < 0 :
        pw = pw_default
        pc=  pc_default
    elif 0 <= normalizedScore < 0.1 :
        pw = pw_default
        pc = 'red'
    elif 0.1 <= normalizedScore < 0.2:
        pw = normalizedScore
        pc = 'orangered3'
    elif 0.2 <= normalizedScore < 0.3:
        pw =  normalizedScore
        pc = 'orangered2'
    elif 0.3 <= normalizedScore < 0.4:
        pw =  normalizedScore
        pc = 'gold' 
    elif 0.4 <= normalizedScore < 0.5:
        pw =  normalizedScore
        pc = 'chartreuse'
    elif 0.5 <= normalizedScore < 0.6:
        pw =  normalizedScore
        pc = 'limegreen' 
    elif 0.6 <= normalizedScore < 0.7:
        pw =  normalizedScore
        pc = 'lime'
    elif 0.7 <= normalizedScore < 0.8:
        pw =  normalizedScore
        pc = 'cyan3' 
    else:
        pw =  normalizedScore
        pc = 'blue' 

    retlist.extend([pw,pc])
    return retlist

# %%
def add_graph_edge(g, head, tail, zscore=None,
                    penwidth=None,
                    color=None,
                    edgeFontcolor="#40e0d0",
                    edgeFontName = "Ariel",
                    edgeFontSize = "5.0",
                    labelfloat = "false",
                    splines = "true",
                    arrowsize="0.4",
                    weight="3",
                    label_prefix="Zscore = ",
                    zScoreMultiplyer=2,
                    calcColorFn=None):
    """
    Adds a styled edge to the Graphviz graph object `g`.

    Parameters:
        g (Digraph): your graph object
        head (str): source node name
        tail (str): destination node name
        zscore (float): value to encode visually (used to compute penwidth and color)
        penwidth (float or str): overrides computed penwidth if provided
        color (str): overrides computed color if provided
        fontcolor (str): label font color
        fontname (str): label font name
        fontsize (str): label font size
        arrowsize (str): edge arrow size
        weight (str): edge weight
        label_prefix (str): prefix for edge label text
        labelfloat (str): whether label floats with edge curvature
        zScoreMultiplyer (float): multiplier for visual scaling
        calcColorFn (function): function to compute [penwidth, color] from zscore
    """

    # Auto-compute visual attributes if not provided
    if zscore is not None and calcColorFn:
        computed = calcColorFn(zscore)
        pw = penwidth if penwidth is not None else computed[0] * zScoreMultiplyer
        pc = color if color is not None else computed[1]
        label = label_prefix + str(round(computed[0], 2))
    else:
        pw = penwidth or "1.0"
        pc = color or "gray"
        label = ""
    #print(f"\033[92mcreating edge with head:\033[38;5;208m{head}\033[92m -> \033[96m{tail}\033[0m")
    g.edge(str(head), str(tail),
           labelfloat=labelfloat,
           label=label,
           fontsize=edgeFontSize,
           fontcolor=edgeFontcolor,
           fontname=edgeFontName,
           penwidth=str(pw),
           weight=weight,
           arrowsize=arrowsize,
           color=pc)
    
def add_edge_tograph(graph, head_name, tail_name, zscore, color_fn):
    """
    Wrapper for add_graph_edge to simplify synaptic connection additions.

    Parameters:
        graph: Graph object to modify.
        pre_name: Node name representing presynaptic neuron.
        post_name: Node name representing postsynaptic neuron.
        zscore: Z-score value representing synaptic weight.
        color_fn: Function to compute edge color from z-score.

    Returns:
        None
    """
    add_graph_edge(
        g=graph,
        head=head_name,
        tail=tail_name,
        zscore=zscore,
        calcColorFn=color_fn
    )

# %%
# Add Edges to Graph

pw_default = 0.1
pc_default = 'gray'
minNormZscore = 0.03
zScoreMultiplyer = 2

skipped_edges_log = {}
nodeDegreeDict = {}
nodeNameZscoreDict = {}
zScoreMultiplyer = 2
valid_nodes = set()
unique_synapse = set()
unique_legs = set()
unused_legs = set()
orphaned_synapses = set()
skipped_edges_log = {}
unused_legs_log = {}

preSynapse = 'preSynapse'
postSynapse = 'postSynapse'

#Create data type for numpy searches
legDtype = [
    ('connection_type', 'U20'),
    ('head_name', 'U60'),
    ('tail_name', 'U60'),
    ('value', 'f8')
]


for head, tail, data in G.edges(data=True):
    
    
    #print('pre= ' + str(head) + 'post= ' + str(tail))
    head_name = G.nodes(data=True)[head]['uname']
    tail_name = G.nodes(data=True)[tail]['uname']
    valid_nodes.update([head_name])
    valid_nodes.update([tail_name])
    
    #if the head's name contains -- then this is a postsynapse syn->neuron
    if "--" in head_name:
        
        try:
            #IMPORTANT - The NEURONs presynaptic dict is used to get the synapses's postZ
            postZscore = preSynNumberDict[head][2]

            #use the head (postsynapse) as a synapse, the tail as a neuron
            #Note: If it's syn ->neuron, then this is a postsynapse
            unique_legs.add((postSynapse,head_name, tail_name, postZscore))
            unique_synapse.add((head,head_name))

        except (KeyError, TypeError, IndexError) as e:
            skipped_edges_log[f"⚠️MissingData {head}->{tail}"] = (
                f"{head} missing in preSynNumberDict or invalid structure: {repr(e)}"
            )
            continue  # skip and move to the next edge
        
        
        #print(f"Postsynaptic leg added with head hash {head}: {head_name} tail hash {tail}: {tail_name} and zscore= {postZscore} ")
        
    #if the tail's name contains -- then this is a presynapse neuron->syn        
    elif "--" in tail_name:
        
        try:      
        
            #IMPORTANT - The NEURONs postsynaptic dict is used to get the -synapses's- postZ
            preZscore = postSynNumberDict[tail][2]

            #use the head as a synapse, the tail here is a neuron node
            unique_legs.add((preSynapse,head_name, tail_name, preZscore))
            unique_synapse.add((tail,tail_name))
        
        except (KeyError, TypeError, IndexError) as e:
            skipped_edges_log[f"⚠️MissingData {head}->{tail}"] = (
                f"{tail} missing in postSynNumberDict or invalid structure: {repr(e)}"
            )
            continue  # skip and move to the next edge
        
        #print(f"Pretsynaptic leg added with head hash {head}: {head_name} tail hash {tail}: {tail_name} and zscore= {preZscore} ")

    else:
        skipped_edges_log[f"{head}->{tail}"] = f"{head_name} and {tail_name} not found"   

        
#Make an np array of all the synapse legs
synLegs_data = np.array(list(unique_legs), dtype=legDtype)

#Now loop through each unique synapse
for uniqueSynHash, uniqueSynName  in unique_synapse:   

        
    #Get the PRE synaptic LEG
    preSynResult = synLegs_data[
        (synLegs_data['tail_name'] == uniqueSynName ) & 
        (synLegs_data['connection_type'] == preSynapse )
    ]
    
    #if we find data, store the tuple into variables
    if len(preSynResult) == 1:
        preSynConnection, headNamePre, tailNamePre, preZscore = preSynResult[0]
    else:
        skipped_edges_log[f"⚠️Error{uniqueSynHash}-{uniqueSynName}"] = f"Edge for {uniqueSynName} not found" 
        
    
    #Get the POST synaptic LEG
    postSynResult = synLegs_data[
        (synLegs_data['head_name'] == uniqueSynName ) & 
        (synLegs_data['connection_type'] == postSynapse )
    ]

    if len(postSynResult) == 1:
        postSynConnection, headNamePost , tailNamePost, postZscore = postSynResult[0]
    else:
        skipped_edges_log[f"⚠️Error{uniqueSynHash}-{uniqueSynName}"] = f"Edge for {uniqueSynName} not found" 
    
    #we should have two legs here
    #pdb.set_trace()
    
    
    #We only want to process associated pre and post legs if they fall below the min
    if  preZscore >= minNormZscore and postZscore >= minNormZscore: 
    
        #Add pre and post legs 
        add_edge_tograph(g, headNamePre, tailNamePre, preZscore, calcColor)
        add_edge_tograph(g, headNamePost, tailNamePost, postZscore, calcColor)

    else:
        
        
        #save the unused legs for.. reasons
        unused_legs.add((preSynConnection,headNamePre, tailNamePre,preZscore))
        unused_legs.add((postSynConnection,headNamePost, tailNamePost,postZscore))
        # unused_legs_log[f"{headNamePre}->{tailNamePre}"] = f"Ignore leg with preZ={preZscore} and postZ={postZscore}"
        unused_legs_log[f"{headNamePre}->{tailNamePre}"] = (f"Ignore leg with preZ={preZscore:.2f} and postZ={postZscore:.2f}")
        
        # Use the pre tailname to note which syanaptic nodes can be removed
        orphaned_synapses.add(tailNamePre)
        
        
print(f"⚠️ Error with {len(skipped_edges_log)} edges not found! ")
display(JSON(skipped_edges_log, expanded=False))
print(f"⚠️ [INFO] {len(unused_legs_log)} edges unused due to low Z-scores")
display(JSON(unused_legs_log, expanded=False))

print( f"number of legs: {len(unique_legs)}" )
# print(f" Valid legs: {unique_legs}")


print(f"number of G nodes: {len(G.nodes())}")
print(f"number of valid_nodes nodes: {len(valid_nodes)}")
# Out:
# ⚠️ Error with 14 edges not found!
# ⚠️ [INFO] 1266 edges unused due to low Z-scores
# number of legs: 3443
# number of G nodes: 1809
# number of valid_nodes nodes: 1809

# %%
#Add nodes to Graph

synaptic_node_log = {}         # for nodes with '--'
non_synaptic_node_log = {}     # for others
node_centrality = {}
sizeMultiplyer = 2
nodeFontSize = "5"

#NODE Attributtes

#macro for name to id conversion
uname_to_id = {G.nodes[n]['uname']: n for n in G.nodes()}




for _node in valid_nodes:
    # if "FB1A_R_2--FB1E_a_R_2" == str(_node):
    #     pdb.set_trace()
    
    if _node in orphaned_synapses:
        #print(f'Node {str(_node)} will not be rendered.')
        continue  # skip disconnected synapse
    
    #Check that this is a synapse
    if '--' in str(_node):
        # centrality_val = node_centrality.get(str(_node))
        raw_id = uname_to_id.get(_node)
        ht = 0.05

        g.node(str(_node),
               shape='circle',
               height=str(ht),
               label='',
               fontsize='5.0',
               fontcolor='orange',
               fixedsize='true',
               color='cyan',
               style='filled')
        
        synaptic_node_log[str(_node)] = {
            "centrality": "NA",
            "status": "rendered" }

    else:
        # if '--' not in str(_node) and it must be a neuron:
        raw_id = uname_to_id.get(_node)
        centrality_val = G.nodes.get(raw_id, {}).get('centrality', 0.0)
        
        centrality2height = centrality_val * sizeMultiplyer
        
        if centrality2height is None:
            print(f"⚠️ Missing centrality for node {_node}")
            centrality2height = 0.0  # fallback value
        
        ht = centrality2height if centrality2height > 0.05 else 0.05
        ht = round(ht, 1)
        centralityLabel = "cent= " + str(ht)
        
        g.node(str(_node),
            shape='circle',
            height= str(ht),
            fontsize=nodeFontSize,
            label= str(_node +"\n" + centralityLabel),
            fixedsize='true',
            fontcolor='white',
            color='brown2',
            style='filled')

        synaptic_node_log[str(_node)] = {
            "centrality": centrality2height
        }

# %%
if os.path.exists("G_auto.svg"):
    os.remove("G_auto.svg")

# %%
g.attr(size='50,50')
g.verbose = True
try:
    g.save('G_auto.gv')
    g.render('G_auto', format = 'svg', view=False)
    
#g.render('G_auto', format = 'png', view=False)
except Exception as e:
    self.raise_error(e, 'There was an error during diagram generation. Please execute "conda install -c anaconda graphviz" in your terminal in your conda environment, or try to install GraphViz globally from https://graphviz.org/download/.')


#Make a filter str to use in the save file name
nFilterStr = nFilter.replace('$','')

characters_to_replace = ['/r', ']', '[', '.', '*', '(', ')']

# Replace each character in the list
for char in characters_to_replace:
    nFilterStr = nFilterStr.replace(char, '')


#noiFileName = str(noi +'_'+ nFilterStr + '_' + str(nSys) + prePost + '_001')
shutil.copy('G_auto.svg', noiFileName + '.svg')
# Out:
# Warning: node 'FB4Z_R_6', graph 'G' size too small for label
# Warning: node 'hDeltaA_02_C2_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R3_C5_2', graph 'G' size too small for label
# Warning: node 'hDeltaA_04_C4_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L5_C7_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_08_C7_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_R5_C1_1', graph 'G' size too small for label
# Warning: node 'FB4Z_R_7', graph 'G' size too small for label
# Warning: node 'hDeltaA_14_C12_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_R1_C1_irreg_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_L7_C8_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_08_C7_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R2_C1_irreg_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_11_C9_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L2_C2_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_12_C10_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L2_C4_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_01_C1_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L4_C6_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R5_C3_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L1_C3_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_01_C1_1', graph 'G' size too small for label
# Warning: node 'FB4Z_L_6', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R6_C4_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_06_C5_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_10_C8_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_R6_C3_1', graph 'G' size too small for label
# Warning: node 'FB4Z_R_4', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_L2_C6_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_07_C6_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_02_C2_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_L3_C7_2', graph 'G' size too small for label
# Warning: node 'FB4Z_R_8', graph 'G' size too small for label
# Warning: node 'FB4Z_L_5', graph 'G' size too small for label
# Warning: node 'hDeltaA_05_C5_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_L4_C8_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L2_C2_2', graph 'G' size too small for label
# Warning: node 'FB4Z_R_3', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L3_C5_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R6_C3_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_13_C11_1', graph 'G' size too small for label
# Warning: node 'hDeltaA_03_C3_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R4_C6_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L3_C3_2', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_L3_C3_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_L1_C2_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_09_C8_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R6_C2_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_R1_C8_1', graph 'G' size too small for label
# Warning: node 'FB4Z_L_8', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R7_C1_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_L3_C7_1', graph 'G' size too small for label
# Warning: node 'hDeltaI_07_C6_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L7_C9_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L4_C4_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L1_C9_irreg_2', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_R3_C6_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L6_C6_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R4_C4_1', graph 'G' size too small for label
# Warning: node 'PFR_b(PB11b)_R4_C5_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_L1_C9_irreg_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R2_C6_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R2_C8_3', graph 'G' size too small for label
# Warning: node 'FS1A(FQ9)_C6_L_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R1_C7_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L1_C3_2', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R4_C6_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L6_C8_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L1_C8_irreg_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R1_C1_irreg_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_R3_C3_2', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_R3_C3_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L3_C5_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R1_C7_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_R2_C4_1', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_R4_C2_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R5_C5_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R1_C2_irreg_1', graph 'G' size too small for label
# Warning: node 'PFR_a(PB11a)_R1_C1_irreg_2', graph 'G' size too small for label
# Warning: node 'PFL2(PB12b)_L5_C9_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L2_C9_irreg_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R3_C5_1', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_R5_C3_2', graph 'G' size too small for label
# Warning: node 'PFL3(PB12c)_L5_C7_2', graph 'G' size too small for label
# Warning: Illegal value sgd for attribute "mode" in graph G - ignored
# Warning: transparent is not a known color.
# 'hDeltaA__50post_001.svg'

# %%
with open('G_auto.svg', 'r') as file:
    data = file.read()

# %%
# Update widgets and widget managers throughout the frontend (included for compatibility)
for i in fbl.widget_manager.widgets:
    if fbl.widget_manager.widgets[i].widget_id not in fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets']:
        fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets'].append(fbl.widget_manager.widgets[i].widget_id)

# Load the diagram
my_client.tryComms({'widget':'GFX', 
                    'messageType': 'loadCircuitFromString', 
                    'data': {'string':data, 'name':'custom'}})

# Run the submodule called onGraphVizLoad2 to make the diagram interactive
my_client.tryComms({'widget':'GFX', 
                    'messageType': 'eval', 
                    'data': {'data':"window.fbl.loadSubmodule('data/FBLSubmodules/onGraphVizLoad2.js');", 'name':'custom'}})

# %%
#Write data out to files:

from collections import defaultdict

# Input and suffix base
input_file = 'G_auto.gv'
#noiFileName = 'neuronX'  # Already set at the start of notebook

# Read original lines
with open(input_file, 'r') as file:
    lines = file.readlines()
    oglines = lines[:]

# Step 1: Clean patterns
patterns = ['_[RL]', '_\d', '_C\d']
replacement_texts = ['', '', '']
for i in range(len(patterns)):
    lines = [re.sub(patterns[i], replacement_texts[i], line) for line in lines]

# Write cleaned file
with open(noiFileName + '.gv', 'w') as postProcessfile:
    postProcessfile.writelines(lines)

# Write original file
with open(noiFileName + '_all.gv', 'w') as postProcessfile:
    postProcessfile.writelines(oglines)

# Regex to capture edge tail, head, and Zscore value
edge_pattern = re.compile(
    r'"([^"]+)"\s*->\s*"([^"]+)"\s*\[.*?label\s*=\s*"Zscore\s*=\s*(\-?\d+\.\d+)"')

edge_dict = defaultdict(list)
other_lines = []

for line in lines:
    match = edge_pattern.search(line)
    if match:
        tail, head, zscore = match.groups()
        edge_key = (tail, head)
        edge_dict[edge_key].append((float(zscore), line))
    else:
        other_lines.append(line)


# Remove any premature closing brace from other_lines
other_lines = [line for line in other_lines if line.strip() != '}']
        
    

# Collect retained and removed edges
retained_edges = []
removed_edges = []

for edge_key, edge_list in edge_dict.items():
    best_edge = max(edge_list, key=lambda x: x[0])
    retained_edges.append(best_edge[1])
    removed_edges.extend(e[1] for e in edge_list if e != best_edge)

    
# Write filtered + retained file
with open(noiFileName + '_002.gv', 'w') as f:
    f.writelines(other_lines + retained_edges)
    f.write('\tsize="50,50"\n')
    f.write('}')

# Optional: write removed edges separately for auditing
with open(noiFileName + '_removed.gv', 'w') as f:
    f.write('digraph G {\n')
    f.writelines(removed_edges)
    f.write('\tsize="50,50"\n')
    f.write('}')

# %% [markdown]
# # Merge Data

# %%
import warnings

def clean_node_id(node_str):
    return node_str.strip('"').strip()

def parse_edge_line(line):
    pattern = r'\"?([^\s\"]+)\"?\s*->\s*\"?([^\s\"]+)\"?.*?label=\"Zscore\s*=\s*([-+]?[0-9]*\.?[0-9]+)\"'
    match = re.search(pattern, line.strip())
    if match:
        head, tail, z_score = match.groups()
        return head.strip('"'), tail.strip('"'), float(z_score), line.strip()
    return None


def merge_graph_files(directory='merge_graphs', output_file='merged_data.gv'):
    if not os.path.exists(directory):
        os.makedirs(directory)
        warnings.warn("Directory 'merge_graphs' not found. Created empty directory. Halting routine.")
        return

    merged_edges = []
    graph_header = []

    for filename in os.listdir(directory):
        if filename.endswith('.gv') and not filename.startswith('merged') and not filename.startswith('unused'):
            with open(os.path.join(directory, filename), 'r') as f:
                lines = f.readlines()

            if not graph_header:
                graph_header = lines[:2]

            body_lines = []  # 🔄 Reset for each file
            layout_directives = ('size=', 'rotation=', 'splines=')

            for line in lines[2:]:
                stripped = line.strip()
                if stripped == '}':
                    continue
                # Only skip lines that *start* with layout directives
                if any(stripped.startswith(directive) for directive in layout_directives):
                    print(f"Skipping layout directive line: {stripped}")
                    continue
                body_lines.append(line)

                
            merged_edges.extend(body_lines)
            print(f"{len(body_lines)} lines of file {filename} merged. Total lines in merged now equals: {len(merged_edges)}")

    # Deduplicate after all files are processed
    edge_dict = {}
    unused_edges = {}
    node_buffer = []
    node_set = set()

    for line in merged_edges:
        parsed = parse_edge_line(line)

        if parsed:
            #print(f"Parsed result: --{parsed}--, Line = {line}")
            parsed_head, parsed_tail, z, full_line = parsed
            key = (parsed_head, parsed_tail)

            # Filtering logic: keep only highest Z-score
            if key not in edge_dict or z > edge_dict[key][0]:
                edge_dict[key] = (z, full_line)
            else:
                # Log discarded edge
                unused_edges.setdefault(key, []).append((z, full_line))
        else:
            # Node handling logic (as discussed earlier)
            line = line.strip()
            if not line:
                continue
            node_buffer.append(line)
            if line.endswith(']'):
                full_node = ' '.join(node_buffer)
                node_set.add(full_node)
                node_buffer = []
                #print(f"Parsed Node found: {full_node}")



                
    output_path_merged = os.path.join(directory, output_file)

    #pdb.set_trace()
    #Write out data to merged file
    with open(output_path_merged, 'w') as out:
        out.writelines(graph_header)
        # Write unique nodes
        for node_line in sorted(node_set):
            out.write(node_line + '\n')
        # Write edges
        for _, (_, line) in edge_dict.items():
            out.write(line + '\n')
        out.write('\tsize="50,50"\n')
        out.write('}\n')

    print(f"✅ Merged graph written to {output_file} with {len(edge_dict)} unique edges.")

    output_path_log = os.path.join(directory, 'unused_log.gv')
    
    with open(output_path_log, 'w') as f:
        for key, entries in unused_edges.items():
            for z_val, line_text in entries:
                f.write(f"# Discarded [{key[0]} -> {key[1]}] with z={z_val}: {line_text}\n")
    print(f"✅ Unused itmes log written to {output_path_log} with {len(unused_edges)}  items.")

############RENAME IF Needed
# currentMergedFileName = 'merged_data.gv'
currentMergedFileName = 'MBON03_prePost_merged_data_v2.gv'

merge_graph_files(output_file=currentMergedFileName)
# Out:
# Skipping layout directive line: size="50,50"
# Skipping layout directive line: size="50,50"
# 2338 lines of file MBON03_PEN_EPG_FB4_CRE_SMP_SIP_30fullCircuit_g3_v1_001_002.gv merged. Total lines in merged now equals: 2338
# Skipping layout directive line: size="50,50"
# Skipping layout directive line: size="50,50"
# 1283 lines of file MBON03__25fullCircuit_g1_v2_001_002.gv merged. Total lines in merged now equals: 3621
# Skipping layout directive line: size="50,50"
# Skipping layout directive line: size="50,50"
# 1744 lines of file MBON03_PEN_25fullCircuit_g2_v2_001_002.gv merged. Total lines in merged now equals: 5365
# ✅ Merged graph written to MBON03_prePost_merged_data_v2.gv with 1257 unique edges.
# ✅ Unused itmes log written to merge_graphs/unused_log.gv with 495  items.

# %% [markdown]
# # Merged Data Filters
# ## Look at the merged data and filter down to a smaller subset

# %%
def extract_zscore(line):
    match = re.search(r'label="[^=]+=\s*([0-9.]+)"', line)
    return float(match.group(1)) if match else 0.0

def find_synapse_legs(synapse, edge_lines):
    """Find both legs of a synapse: pre and post edges."""
    legs = []
    for line in edge_lines:
        parts = line.strip().split('->')
        if len(parts) != 2:
            raise ValueError(f"Malformed edge line at index {i}: {line.strip()}")
            continue
        src = parts[0].strip().strip('"')
        tgt = parts[1].split()[0].strip().strip('"')
        if src == synapse or tgt == synapse:
            z = extract_zscore(line)
            legs.append((src, tgt, z, line))
    return legs

def get_base_graph_file(directory='merge_graphs', override=None):
    """Return the path to the base graph file, either via override or latest merged_*.gv."""
    if override:
        path = os.path.join(directory, override)
        if not os.path.exists(path):
            raise FileNotFoundError(f"Override file '{override}' not found in {directory}")
        return path

    merged_files = [f for f in os.listdir(directory) if 'merged' in f and f.endswith('.gv')]
    if not merged_files:
        raise FileNotFoundError("No merged_*.gv files found in the directory.")
    
    merged_files.sort(key=lambda f: os.path.getmtime(os.path.join(directory, f)), reverse=True)
    return os.path.join(directory, merged_files[0])


def filter_graph(directory='merge_graphs', threshold=0.5):
    # Load lines
    with open(get_base_graph_file(directory), 'r') as f:
        lines = f.readlines()

    # Separate node and edge lines
    node_lines = [line for line in lines if '->' 
              not in line 
              and '[' in line and not line.strip().startswith(('graph [', 'node [', 'edge ['))]
    
    edge_lines = [line for line in lines if '->' in line]

    # Extract all node IDs and synapse nodes
    all_nodes = set()
    synapse_nodes = set()
    node_dict = {}

    for line in node_lines:
        tokens = line.strip().split()
        if tokens:
            node_id = tokens[0].strip('"')
            all_nodes.add(node_id)
            node_dict[node_id] = line
            if '--' in node_id:
                synapse_nodes.add(node_id)

    accepted_edges = []
    nodes_in_accepted_edges = set()
    rejected_synapses = set()

    # Evaluate each synapse as a unit
    for synapse in synapse_nodes:
        legs = find_synapse_legs(synapse, edge_lines)

        if len(legs) != 2:
            print(f"⚠️ Synapse {synapse} has {len(legs)} legs, skipping.")
            continue

        z_scores = [leg[2] for leg in legs]
        if any(z >= threshold for z in z_scores):
            for src, tgt, z, line in legs:
                accepted_edges.append(line)
                nodes_in_accepted_edges.update([src, tgt])
        else:
            rejected_synapses.add(synapse)

    # Filter nodes based on accepted edges
    filtered_nodes = [
        line for node, line in node_dict.items()
        if node in nodes_in_accepted_edges and node not in rejected_synapses
    ]

    # Optional: log dropped nodes
    dropped_nodes = all_nodes - nodes_in_accepted_edges - rejected_synapses
    if dropped_nodes:
        print(f"Dropped {len(dropped_nodes)} nodes: {sorted(dropped_nodes)}")

    return filtered_nodes, accepted_edges

if __name__ == "__main__":
    directory = 'merge_graphs'
    override_filename = None  # e.g. 'merged_subset.gv' if you want to override
    output_file = 'filtered_output.gv'
    
    #######################################
    ######### Set Threshold ###############
    #######################################
    
    tempThreshold = 0.3

    try:
        filtered_nodes, accepted_edges = filter_graph(directory, threshold=tempThreshold)
        print(f"✅ Filtered graph written to {output_file} with {len(filtered_nodes)} nodes and {len(accepted_edges)} edges.")
        
    except Exception as e:
        print(f"❌ Error: {e}")
        traceback.print_exc()

        

    grouped_nodes = defaultdict(list)
    ungrouped_nodes = []

    for line in filtered_nodes:
        tokens = line.strip().split()
        if not tokens:
            continue

        node_id = tokens[0].strip('"')

        if '--' in node_id:
            # ✅ Synapse node: keep for output, but don't group
            ungrouped_nodes.append(line)
        else:
            # ✅ Neuron node: group by prefix
            prefix = node_id[:3]
            grouped_nodes[prefix].append(line)

        
        
    
    # Write output file with header and footer
    with open(input_file, 'r') as f:
        lines = f.readlines()
    graph_header = lines[:2]
    graph_footer = lines[-2:]

    # Write output
    with open(output_file, 'w') as out:
        out.writelines(graph_header)

        # ✅ All writes must be inside this block
        for prefix in sorted(grouped_nodes):
            out.write(f"subgraph cluster_{prefix} {{\n")
            out.write(f'    label = "{prefix} Group";\n')
            out.write("    style = none;\n    color = black;\n ")
            for node_line in sorted(grouped_nodes[prefix]):
                out.write("    " + node_line.strip() + '\n')
            out.write("}\n")
            
        # ✅ Write synapse nodes outside any group
        for node_line in sorted(ungrouped_nodes):
            out.write("    " + node_line.strip() + '\n')

        for edge_line in sorted(set(accepted_edges)):
            out.write(edge_line.strip() + '\n')

        out.writelines(graph_footer)
# Out:
# Dropped 2 nodes: ['CRE043_a(ADM10)', 'PPL106(a3)']
# ✅ Filtered graph written to filtered_output.gv with 432 nodes and 676 edges.

# %% [markdown]
# # Other helper code

# %% [markdown]
# ## Python routine that scans the G_auto.gv file-identifies all edges with the same head and tail. This can pinpoint which ones might be collapsed due to concentrate=true.

# %%
import re
from collections import defaultdict

def find_edges_by_terminal_node(dot_path):
    edge_map = defaultdict(list)

    with open(dot_path, 'r') as f:
        for line in f:
            # Match basic edge syntax
            match = re.match(r'\s*"([^"]+)"\s*->\s*"([^"]+)"', line)
            if match:
                source, target = match.groups()
                # Extract final part if it's a compound edge
                simplified_source = source.split('--')[-1]
                simplified_target = target.split('--')[-1]
                key = (simplified_source, simplified_target)
                edge_map[key].append(line.strip())

    # Filter for multiple edges per neuron pair
    duplicates = {k: v for k, v in edge_map.items() if len(v) > 1}

    print(f"Found {len(duplicates)} terminal edge collisions:\n")
    for (src, tgt), lines in duplicates.items():
        print(f'Edges ending at "{tgt}" from "{src}": {len(lines)}')
        for l in lines:
            print(f'  {l}')
        print()

# Run it
find_edges_by_terminal_node('MBON13__35pre_001_002.gv')

# %% [markdown]
# ### Confirm digraph setup if needed

# %%
nodes = clean_graphviz_node_names(g.source)
edges = get_graphviz_edges(g.source)

unique_nodes = list(set(nodes))
print(f"🧠 Unique Nodes Actually Rendered: {len(unique_nodes)}")

# Force full output
import pprint
print("\n🧠 Full Node List:")
pprint.pprint(nodes, width=160)

print("\n🔗 Full Edge List:")
pprint.pprint(edges, width=160)
# Out:
# 🧠 Total Nodes Rendered: 0
# [] ...
#
# 🔗 Total Edges Rendered: 0
# 🧠 Unique Nodes Actually Rendered: 0
#
# 🧠 Full Node List:
# []
#
# 🔗 Full Edge List:
# []

# %%
dot_node_names = set(valid_nodes)  # based on your rendering logic
g_nodes = set(G.nodes())

extra_rendered_nodes = dot_node_names - g_nodes
print("🕵️ Nodes rendered but not present in graph:", extra_rendered_nodes)

# %%
print(f"✅ Synaptic nodes rendered: {len(synaptic_node_log)}")
display(JSON(synaptic_node_log, expanded=False))

print(f"⚠️ Non-synaptic nodes: {len(non_synaptic_node_log)}")
display(JSON(non_synaptic_node_log, expanded=False))

# expected_nodes = set(valid_nodes)
# unexpected = set(unique_nodes) - expected_nodes

# print(f"⚠️ Unexpected node names: {len(unexpected)}")
# from pprint import pprint
# pprint(list(unexpected))
# Out:
# ✅ Synaptic nodes rendered: 56
# ⚠️ Non-synaptic nodes: 0

# %%
import re

def clean_graphviz_node_names(dot_str):
    # Match everything in double quotes
    all_strings = re.findall(r'"([^"]+)"', dot_str)

    # Remove strings clearly used as edge labels
    label_noise = re.compile(r"Zscore = \d+(\.\d+)?")
    filtered_nodes = [s for s in all_strings if not label_noise.match(s)]

    # Keep only nodes that appear either in edge definitions or node blocks
    edge_pattern = re.compile(r'"([^"]+)"\s*->\s*"([^"]+)"')
    node_names_in_edges = set(sum(edge_pattern.findall(dot_str), ()))

    # Node candidates that look like IDs and appear in edge mappings
    node_names = [n for n in filtered_nodes if n in node_names_in_edges]

    print(f"🧠 Total Nodes Rendered: {len(node_names)}")
    print(node_names[:50], '...')

    return node_names

def get_graphviz_edges(dot_str):
    edge_pattern = re.compile(r'"([^"]+)"\s*->\s*"([^"]+)"')
    edges = edge_pattern.findall(dot_str)

    print(f"\n🔗 Total Edges Rendered: {len(edges)}")
    for src, dst in edges[:10]:
        print(f"{src} → {dst}")
    
    return edges

# %%
# # STEP 1: Render and save original graph
# g.attr(size='50,50')
# g.verbose = True
# try:
#     g.save('G_auto.gv')
#     g.render('G_auto', format='svg', view=False)
# except Exception as e:
#     self.raise_error(e, 'There was an error during diagram generation. Please execute "conda install -c anaconda graphviz" in your terminal in your conda environment, or try to install GraphViz globally from https://graphviz.org/download.')

# # STEP 2: Load .gv file as text
# with open("G_auto.gv", "r") as f:
#     gv_text = f.read()

# # STEP 3: Find declared and connected nodes
# declared_nodes = set(
#     match for match in re.findall(r'(\S+)\s*\[label=', gv_text)
#     if '--' not in match 
#     )


# edge_nodes = set()
# for src, dst in re.findall(r'(\S+)\s*->\s*(\S+)', gv_text):
#     edge_nodes.add(src.strip('"'))
#     edge_nodes.add(dst.strip('"'))

# # STEP 4: Find orphaned nodes
# orphans = declared_nodes - edge_nodes

# # STEP 5: Log orphaned nodes
# with open("G_orphan_log.txt", "w") as log_file:
#     for o in sorted(orphans):
#         log_file.write(f"Orphaned node removed: {o}\n")

# # STEP 6: Strip orphaned node definitions from source
# cleaned_lines = []
# for line in gv_text.splitlines():
#     if not any(line.strip().startswith(o + ' ') for o in orphans):
#         cleaned_lines.append(line)

# cleaned_gv = '\n'.join(cleaned_lines)

# # STEP 7: Render cleaned graph
# G_clean = Source(cleaned_gv)
# G_clean.render('G_cleaned', format='svg', view=False)

# # STEP 8: Filename sanitization
# nFilterStr = nFilter.replace('$','')
# for char in ['/r', ']', '[', '.', '*', '(', ')']:
#     nFilterStr = nFilterStr.replace(char, '')

# noiFileName = f"{noi}_{nFilterStr}_{nSys}{prePost}_001"
# shutil.copy('G_cleaned.svg', f"{noiFileName}.svg")

# %%
gv_text = g.source

# Step 1: Extract all nodes that appear in edge definitions
edges = re.findall(r'(\S+)\s*->\s*(\S+)', gv_text)
edge_nodes = set()
for src, dst in edges:
    edge_nodes.add(src.strip('"'))
    edge_nodes.add(dst.strip('"'))

# Step 2: Extract all declared nodes with label assignments
declared_nodes = set(re.findall(r'(\S+)\s* \[label=', gv_text))
declared_nodes = set(n.strip('"') for n in declared_nodes)

# Step 3: Find nodes declared but not used in any edge
orphan_nodes = declared_nodes - edge_nodes

# Step 4: Display results
print(f"🧠 Declared nodes: {len(declared_nodes)}")
print(f"🔗 Connected nodes: {len(edge_nodes)}")
print(f"🚫 Orphaned nodes: {len(orphan_nodes)}")
print("Orphans:")
for n in sorted(orphan_nodes):
    print("  -", n)

# %%
# Extract all nodes from each leg tuple (excluding the synapse type and weight)
missing_nodes = set()
for leg in unique_legs:
    _, node1, node2, _ = leg
    for node in [node1, node2]:
        print(node)
        if node not in valid_nodes:
            missing_nodes.add(node)

# Print out the missing nodes
for node in sorted(missing_nodes):
    print(f"Missing node: {node}")

# %%
# # Setup

# pw_default = 0.1
# pc_default = 'gray'
# minNormZscore = 0.2
# zScoreMultiplyer = 2

# skipped_edges_log = {}
# nodeDegreeDict = {}
# nodeNameZscoreDict = {}
# zScoreMultiplyer = 2
# penSettings = []
# valid_nodes = set()
# unique_nodes = set()
# skipped_edges_log = {}

# # #macro for name to id conversion
# # uname_to_id = {G.nodes[n]['uname']: n for n in G.nodes()}

# for head, tail, data in G.edges(data=True):
    
    
#     #print('pre= ' + str(head) + 'post= ' + str(tail))
#     pre_name = G.nodes(data=True)[head]['uname']
#     post_name = G.nodes(data=True)[tail]['uname']
#     valid_nodes.update([pre_name])
#     valid_nodes.update([post_name])


#     #check that the head and tail are in or z score dicts
#     #Each head and tail representa either syn->neuron or neuron->syn: NOT neur->neur
#     if head in preSynNumberDict.keys():

#         Zscore  = preSynNumberDict[head][2]
#         penSettings =  calcColor(Zscore)
        
#         add_graph_edge(g,
#             head=pre_name,
#             tail=post_name,
#             zscore = Zscore,
#             calcColorFn=calcColor)
        
        
#     elif tail in postSynNumberDict.keys():
#         Zscore = postSynNumberDict[tail][2]
#         penSettings = calcColor(Zscore)
    
#         #Get desired edge color and width
#         pw_pre = penSettings[0] * zScoreMultiplyer #pen width
#         pc_pre = penSettings[1]                    #pen color
        
#         add_graph_edge(g,
#                 head=pre_name,
#                 tail=post_name,
#                 zscore = Zscore,
#                 calcColorFn=calcColor)
#     else:
#         skipped_edges_log[f"{head}->{tail}"] = f"{pre_name} and {post_name} not found"         
                       
        
# print(f"⚠️ Skipped {len(skipped_edges_log)} synapse edges due to low Z-scores")
# from IPython.display import JSON, display
# display(JSON(skipped_edges_log, expanded=False))
# print(f"number of G nodes: {len(G.nodes())}")
# print(f"number of valid_nodes nodes: {len(valid_nodes)}")

# %%
my_client.tryComms??
# Out:
# Signature: my_client.tryComms(a)
# Source:
#     def tryComms(self, a):
#         """Communication function to communicate with a JupyterLab frontend if one exists.
#
#         # Arguments
#             a (obj): Arbitrarily formatted data to be sent via communication.
#         """
#         try:
#             for i in fbl.widget_manager.widgets:
#                 if fbl.widget_manager.widgets[i].widget_id not in fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets']:
#                     fbl.client_manager.clients[fbl.widget_manager.widgets[i].client_id]['widgets'].append(fbl.widget_manager.widgets[i].widget_id)
#         except:
#             pass
#         try:
#             self.FBLcomm.send(data=a)
#         except:
#             pass
# File:      ~/miniconda/envs/ffbo/lib/python3.9/site-packages/flybrainlab/Client.py
# Type:      method

# %%
fbl.widget_manager??
# Out:
# Type:        WidgetManager
# String form: <flybrainlab.widget.WidgetManager object at 0x7fd8939e8ac0>
# File:        ~/miniconda/envs/ffbo/lib/python3.9/site-packages/flybrainlab/widget.py
# Source:
# class WidgetManager(object):
#     """Widget Manager class that keeps track of all widgets associated with the current FBLClient session.
#
#     # Attributes:
#         widgets (dict): a dictionary of instances of Widget.
#         _comms (dict): all comm objects opend for this client.
#         last_active (Widget): last active widget based on comm
#     """
#
#     def __init__(self):
#         self._comms = OrderedDict()
#         self.widgets = OrderedDict()
#         self.callback_manager = CallbackManager()
#         self.last_active = None
#
#     def add_widget(self, widget_id, client_id, widget_type, comm_target):
#         """Add a widget to manager.
#
#         # Returns:
#
#         """
#         comm = self.find_comm(comm_target=comm_target) # Try to find a comm object
#         if not comm: # Create comm if does not exist
#             comm = Comm(target_name=comm_target)
#             self._comms[widget_id] = comm
#
#             @comm.on_msg
#             def handle_msg(msg):
#                 comm_id = msg["content"]["comm_id"]
#                 data = msg["content"]["data"]
#                 nonlocal self
#                 widget = self.find_widget_by_comm_id(comm_id)
#                 self.last_active = widget
#                 widget.msg_data = data
#                 widget.parse_data(data)
#                 if data == "dispose":
#                     widget.isDisposed = True
#                 self.callback_manager.run(comm_id, data)
#
#             @comm.on_close
#             def handle_close(msg):
#                 comm_id = msg["content"]["comm_id"]
#                 nonlocal self
#                 widget = self.find_widget_by_comm_id(comm_id)
#                 widget.commOpen = False
#
#         if widget_id not in self.widgets:
#             self.widgets[widget_id] = Widget(
#                 widget_type=widget_type,
#                 widget_id=widget_id,
#                 client_id = client_id,
#                 model=None,
#                 comm=comm,
#                 isDisposed=False,
#                 msg_data=None,
#             )
#         self.last_active = self.widgets[widget_id]
#
#         # make sure that comm is open
#         comm.open()
#
#     def find_comm(self, comm_id=None, comm_target=None):
#         """Find a comm object either by id or by target name
#         """
#         if comm_id:
#             comm = [c for c in self._comms.values() if c.comm_id == comm_id]
#         elif comm_target:
#             comm = [c for c in self._comms.values() if c.target_name == comm_target]
#         else:
#             comm = []
#         if len(comm) == 1:
#             return comm[0]
#         else:
#             return None
#
#     def find_widget_by_comm_id(self, comm_id):
#         w = [w for w in self.widgets.values() if w.comm.comm_id == comm_id]
#         if len(w) == 1:
#             return w[0]
#         else:
#             return None
#
#     def send_data(self, widget_id, data):
#         if widget_id in self.widgets:
#             self.widgets[widget_id].send_data(data)
#             self.last_active = self.widgets[widget_id]
